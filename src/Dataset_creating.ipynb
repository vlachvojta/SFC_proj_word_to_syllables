# %% [markdown]
# # Dataset creating
#
# This notebook includes some basic examples of creating the word-to-syllables dataset.

# %%
import requests
from bs4 import BeautifulSoup
import re
import os
import time

# %% [markdown]
# ## Getting syllables from "Ústav jazyka českého" website
#
# [https://prirucka.ujc.cas.cz/](https://prirucka.ujc.cas.cz/?slovo=cht%C3%ADt)
#
# Using address: prirucka.ujc.cas.cz/?slovo={word}
#
# NOT WORKING:
# Unfortunately the server seems to monitor web-scraping and therefore doesn't allow script to run repeatedly.

# %%
words = ['mravenečník', 'který', 'mít', 'jako', 'moci', 'svůj', 'tento',
         'všechen', 'jeden', 'člověk', 'vypadat', 'pohled', 'dokonce', 'možnost']

input_file = os.path.join('..', 'dataset', 'syn2015_lemma_cba.txt')

with open(input_file) as f:
    words = [line.rstrip() for line in f]

print(f'{len(words)} words loaded from {input_file}')
print(f'for example: {words[:min(10, len(words))]}')
# Out:
# 38815 words loaded from ../dataset/syn2015_lemma_cba.txt
# for example: ['být', 'a', 'se', 'v', 'na', 'ten', 's', 'že', 'on', 'z']

# %%
# word = 'mravenečník'
separated_words = []
error_words = []
timeout_words = []
for word in words:
    print(word, end=' =>', flush=True)
    try:
        response = requests.get(f'https://prirucka.ujc.cas.cz/?slovo={word}', timeout=10)
    except requests.exceptions.Timeout:
        timeout_words.append(word)
        print()
        continue

    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    classes = soup.findAll("p", {"class": "polozky"})
    if not classes:
        error_words.append(word)
        print()
        continue
    syllables_line = classes[0].text
    syllables = syllables_line.replace('dělení: ', '')
    syllables = re.match(r'[a-záéěíóúůýčďňřšťž\-]+', syllables).group(0)

    # TODO: write more complex checks (syllables.replace('-', '') == word etc.)

    print('\t', syllables, end='')
    print()
    separated_words.append((word, syllables))
    print(separated_words)
    time.sleep(10)

print(f'{len(separated_words)} words separated')
print(f'for example: {separated_words[:min(10, len(separated_words))]}')

print(f'{len(error_words)} words with errors')
print(f'for example: {error_words[:min(10, len(error_words))]}')

# %% [markdown]
# ## Getting syllables from pronounciation dataset

# %%
import pandas as pd

csv_file = os.path.join('..', 'dataset', 'ssc_29-06-16', 'ssc_29-06-16.csv')
df = pd.read_csv(csv_file, sep=';')
df = df[['Ortho', 'Syllab']]
df.rename(columns={'Ortho': 'Word', 'Syllab': 'Pronounciation'}, inplace=True)
# all string in df['Pronounciation] to lowercase
df['Pronounciation'] = df['Pronounciation'].str.lower()
df = df[~df["Pronounciation"].str.contains('-')]
df = df[~df["Word"].str.contains(' ')]
df['Word'] = df['Word'].str.lower()
df['Syllables'] = ''
# df = df.head(20)
df
# Out:
#              Word Pronounciation Syllables
# 0               a              a
# 1         abatyše     a.ba.ti.še
# 2            abbé           a.bē
# 3        abdikace   ap.di.ka.tse
# 4       abdikovat   ap.di.ko.vat
# ...           ...            ...       ...
# 49358  žvatlavost   žva.tla.vost
# 49359    žvatlavý     žva.tla.vī
# 49360     žvýkací     žvī.ka.tsī
# 49361    žvýkačka    žvī.katš.ka
# 49362      žvýkat        žvī.kat
#
# [45097 rows x 3 columns]

# %%
df['Word_len']  = df['Word'].str.len()
# Out:
#            Word Pronounciation Syllables  Word_len
# 2          abbé           a.bē                   4
# 172    achilles       a.xi.les                   8
# 170       achát          a.xāt                   5
# 171    achátový     a.xā.to.vī                   8
# 119    aerotaxi  a.e.ro.tak.si                   8
# ...         ...            ...       ...       ...
# 49191     žínka         žīn.ka    žín-ka         5
# 49192       žír            žīr       žír         3
# 49197     žírný         žīr.nī    žír-ný         5
# 49198       žít            žīt       žít         3
# 49305     žňový         žňo.vī    žňo-vý         5
#
# [45097 rows x 4 columns]

# %%
def pronounciation_to_syllables(pronounciation, word):
    syllables = ''
    for char in pronounciation:
        if char == '.':
            syllables += '-'
        else:
            syllables += word[0]
            word = word[1:]
    return syllables

def pron_in_list(pron_list, pronounciation):
    for pron in pron_list:
        if pronounciation.startswith(pron):
            return True, len(pron)
    return False, 0


def get_syllables(row):
    pronounciation_len = len(row['Pronounciation'].replace('.', ''))
    if pronounciation_len == len(row['Word']):
        row['Syllables'] = pronounciation_to_syllables(row['Pronounciation'], row['Word'])
    else:
        pronounciation = row['Pronounciation']
        word = row['Word']
        print(word, pronounciation)
        syllables = ''
        # offset = 0
        while len(word) > 0:
            if not pronounciation:
                break
            if (word[0] == pronounciation[0] or 
                (len(pronounciation) > 1 and pronounciation[1] == '.') or
                (len(word) > 1 and len(pronounciation) > 1 and word[1] == pronounciation[1])):
                syllables += word[0]
                word = word[1:]
                pronounciation = pronounciation[1:]
            elif word[0] in pronounciation_pairs.keys():
                pron_list = [pronounciation_pairs[word[0]]] if isinstance(pronounciation_pairs[word[0]], str) else pronounciation_pairs[word[0]]

                is_pron_in_list, pron_len = pron_in_list(pron_list, pronounciation)
                if is_pron_in_list:
                    syllables += word[0]
                    word = word[1:]
                    pronounciation = pronounciation[pron_len:]
                else:
                    print(f'\tBREAKING! word: {word}, syllables: {syllables}, pronounciation: {pronounciation}')
                    break
            else:
                print(f'\tNothing found. BREAKING! word: {word}, syllables: {syllables}, pronounciation: {pronounciation}')
                break

            if pronounciation and pronounciation[0] == '.':
                syllables += '-'
                pronounciation = pronounciation[1:]
        if syllables.replace('-', '') == row['Word']:
            row['Syllables'] = syllables
            print(f'\t{syllables}')
        else:
            print(f'\tLengths do not match. Word: {row["Word"]}, syllables: {syllables}, pronounciation: {row["Pronounciation"]} ({row["Word"]})')

    return row

pronounciation_pairs = {
    'á': ['ā', 'jā'],
    'b': 'p',
    'c': 'ts',
    'č': 'tš',
    'e': ['je', 'ē'],
    'é': ['ē', 'jē'],
    'ě': 'je',
    'i': 'ī',
    'í': 'ī',
    'n': 'ň',
    'p': 'b',
    'o': 'jo',
    'ó': 'ō',
    'u': 'ju',
    'ů': 'ū',
    'ú': 'ū',
    'y': 'i',
    'ý': 'ī',
    'x': ['ks', 'k.s'],
    'z': 's',
    # 'ř': 'rž',
    # 'š': 'šč',
    # 'ž': 'zž',
    # 'ť': 'tť',
    # 'ď': 'dď',
}

df_new = df[df['Syllables'] == ''].apply(get_syllables, axis=1)
df_old = df[df['Syllables'] != '']

df = pd.concat([df_new, df_old])

df.sort_values(by=['Syllables', 'Word'], inplace=True)

df
# Out:
# abbé a.bē
# 	BREAKING! word: bé, syllables: a-b, pronounciation: ē
# 	Lengths do not match. Word: abbé, syllables: a-b, pronounciation: a.bē (abbé)
# abdikace ap.di.ka.tse
# 	ab-di-ka-ce
# abeceda a.be.tse.da
# 	a-be-ce-da
# abecední a.be.tse.dňī
# 	a-be-ce-dní
# abiturient a.bi.tu.ri.jent
# 	a-bi-tu-ri-ent
# abiturientka a.bi.tu.ri.jen.tka
# 	a-bi-tu-ri-en-tka
# abiturientský a.bi.tu.ri.jents.kī
# 	a-bi-tu-ri-ents-ký
# absces aps.tses
# 	abs-ces
# absence ap.sen.tse
# 	ab-sen-ce
# absolutisticky ap.so.lu.tis.tits.ki
# 	ab-so-lu-tis-tic-ky
# absolutistický ap.so.lu.tis.tits.kī
# 	ab-so-lu-tis-tic-ký
# absolutorium ap.so.lu.to.ri.jum
# 	ab-so-lu-to-ri-um
# absorpce ap.sorp.tse
# 	ab-sorp-ce
# absorpční ap.sorp.tšňī
# 	ab-sorp-ční
# abstence ap.sten.tse
# 	ab-sten-ce
# abstinence ap.sti.nen.tse
# 	ab-sti-nen-ce
# abstrakce aps.trak.tse
# 	abs-trak-ce
# abstrakční aps.trak.tšňī
# 	abs-trak-ční
# aceton a.tse.ton
# 	a-ce-ton
# acetonový a.tse.to.no.vī
# 	a-ce-to-no-vý
# acetylen a.tse.ti.lēn
# 	a-ce-ty-len
# acetylenový a.tse.ti.le.no.vī
# 	a-ce-ty-le-no-vý
# acylpyrin a.tsil.pi.rīn
# 	a-cyl-py-rin
# ač atš
# 	ač
# áčko ātš.ko
# 	áč-ko
# ačkoli atš.ko.li
# 	ač-ko-li
# ačkoliv atš.ko.lif
# 	Nothing found. BREAKING! word: v, syllables: ač-ko-li, pronounciation: f
# 	Lengths do not match. Word: ačkoliv, syllables: ač-ko-li, pronounciation: atš.ko.lif (ačkoliv)
# adaptace a.dap.ta.tse
# 	a-dap-ta-ce
# adié a.di.jē
# 	a-di-é
# administrace a.dmi.nis.tra.tse
# 	a-dmi-nis-tra-ce
# administrační a.dmi.nis.tra.tšňī
# 	a-dmi-nis-tra-ční
# adopce a.dop.tse
# 	a-dop-ce
# adopční a.dop.tšňī
# 	a-dop-ční
# adverbiální a.dver.bi.jāl.ňī
# 	a-dver-bi-ál-ní
# adverbium a.dver.bi.jum
# 	a-dver-bi-um
# advokacie a.dvo.ka.tsi.je
# 	a-dvo-ka-ci-e
# aerodynamický a.e.ro.di.na.mits.kī
# 	a-e-ro-dy-na-mic-ký
# aerolinie a.e.ro.lī.ni.je
# 	a-e-ro-li-ni-e
# aerotaxi a.e.ro.tak.si
# 	BREAKING! word: i, syllables: a-e-ro-tax-, pronounciation: si
# 	Lengths do not match. Word: aerotaxi, syllables: a-e-ro-tax-, pronounciation: a.e.ro.tak.si (aerotaxi)
# afázie a.fā.zi.je
# 	a-fá-zi-e
# agitace a.gi.ta.tse
# 	a-gi-ta-ce
# agitačně a.gi.ta.tšňe
# 	BREAKING! word: ě, syllables: a-gi-ta-čn, pronounciation: e
# 	Lengths do not match. Word: agitačně, syllables: a-gi-ta-čn, pronounciation: a.gi.ta.tšňe (agitačně)
# agitační a.gi.ta.tšňī
# 	a-gi-ta-ční
# aglomerace a.glo.me.ra.tse
# 	a-glo-me-ra-ce
# agnosticismus a.gnos.ti.tsi.zmus
# 	a-gnos-ti-ci-smus
# agnosticizmus a.gnos.ti.tsi.zmus
# 	a-gnos-ti-ci-zmus
# agonie a.go.ni.je
# 	a-go-ni-e
# agrárnický a.grār.nits.kī
# 	a-grár-nic-ký
# agrobiologie a.gro.bi.jo.lo.gi.je
# 	a-gro-bi-o-lo-gi-e
# agronomie a.gro.no.mi.je
# 	a-gro-no-mi-e
# agrotechnik a.gro.te.xnik
# 	BREAKING! word: chnik, syllables: a-gro-te-, pronounciation: xnik
# 	Lengths do not match. Word: agrotechnik, syllables: a-gro-te-, pronounciation: a.gro.te.xnik (agrotechnik)
# agrotechnika a.gro.te.xni.ka
# 	BREAKING! word: chnika, syllables: a-gro-te-, pronounciation: xni.ka
# 	Lengths do not match. Word: agrotechnika, syllables: a-gro-te-, pronounciation: a.gro.te.xni.ka (agrotechnika)
# achát a.xāt
# 	BREAKING! word: chát, syllables: a-, pronounciation: xāt
# 	Lengths do not match. Word: achát, syllables: a-, pronounciation: a.xāt (achát)
# achátový a.xā.to.vī
# 	BREAKING! word: chátový, syllables: a-, pronounciation: xā.to.vī
# 	Lengths do not match. Word: achátový, syllables: a-, pronounciation: a.xā.to.vī (achátový)
# achilles a.xi.les
# 	BREAKING! word: chilles, syllables: a-, pronounciation: xi.les
# 	Lengths do not match. Word: achilles, syllables: a-, pronounciation: a.xi.les (achilles)
# akademicky a.ka.de.mits.ki
# 	a-ka-de-mic-ky
# akademický a.ka.de.mits.kī
# 	a-ka-de-mic-ký
# akademička a.ka.de.mitš.ka
# 	a-ka-de-mič-ka
# akademie a.ka.de.mi.je
# 	a-ka-de-mi-e
# akce ak.tse
# 	ak-ce
# akcelerace ak.tse.le.ra.tse
# 	ak-ce-le-ra-ce
# akcent ak.tsent
# 	ak-cent
# akcept ak.tsept
# 	ak-cept
# akceptovat ak.tsep.to.vat
# 	ak-cep-to-vat
# akcie ak.tsi.je
# 	ak-ci-e
# akcionář ak.tsi.jo.nāř
# 	ak-ci-o-nář
# akciový ak.tsi.jo.vī
# 	ak-ci-o-vý
# akční ak.tšňī
# 	ak-ční
# aklamace a.kla.ma.tse
# 	a-kla-ma-ce
# aklimatizace a.kli.ma.ti.za.tse
# 	a-kli-ma-ti-za-ce
# aklimatizační a.kli.ma.ti.za.tšňī
# 	a-kli-ma-ti-za-ční
# akomodace a.ko.mo.da.tse
# 	a-ko-mo-da-ce
# akreditace a.kre.di.ta.tse
# 	a-kre-di-ta-ce
# akrobacie a.kro.ba.tsi.je
# 	a-kro-ba-ci-e
# akrobatický a.kro.ba.tits.kī
# 	a-kro-ba-tic-ký
# aktivizace ak.ti.vi.za.tse
# 	ak-ti-vi-za-ce
# aktualizace ak.tu.a.li.za.tse
# 	ak-tu-a-li-za-ce
# akumulace a.ku.mu.la.tse
# 	a-ku-mu-la-ce
# akumulační a.ku.mu.la.tšňī
# 	a-ku-mu-la-ční
# akustický a.kus.tits.kī
# 	a-kus-tic-ký
# akváriový a.kvā.ri.jo.vī
# 	a-kvá-ri-o-vý
# akvárium a.kvā.ri.jum
# 	a-kvá-ri-um
# akvizice a.kvi.zi.tse
# 	a-kvi-zi-ce
# alegoricky a.le.go.rits.ki
# 	a-le-go-ric-ky
# alegorický a.le.go.rits.kī
# 	a-le-go-ric-ký
# alegorie a.le.go.ri.je
# 	a-le-go-ri-e
# alergický a.ler.gits.kī
# 	a-ler-gic-ký
# alergie a.ler.gi.je
# 	a-ler-gi-e
# alexandrin a.lek.san.drīn
# 	Nothing found. BREAKING! word: andrin, syllables: a-lex-, pronounciation: san.drīn
# 	Lengths do not match. Word: alexandrin, syllables: a-lex-, pronounciation: a.lek.san.drīn (alexandrin)
# algebraický al.ge.bra.jits.kī
# 	BREAKING! word: ický, syllables: al-ge-bra-, pronounciation: jits.kī
# 	Lengths do not match. Word: algebraický, syllables: al-ge-bra-, pronounciation: al.ge.bra.jits.kī (algebraický)
# algoritmický al.go.ri.tmits.kī
# 	al-go-ri-tmic-ký
# algoritmizace al.go.ri.tmi.za.tse
# 	al-go-ri-tmi-za-ce
# alchymista al.xi.mis.ta
# 	BREAKING! word: chymista, syllables: al-, pronounciation: xi.mis.ta
# 	Lengths do not match. Word: alchymista, syllables: al-, pronounciation: al.xi.mis.ta (alchymista)
# aliance a.li.jan.tse
# 	Nothing found. BREAKING! word: ance, syllables: a-li-, pronounciation: jan.tse
# 	Lengths do not match. Word: aliance, syllables: a-li-, pronounciation: a.li.jan.tse (aliance)
# alibistický a.li.bis.tits.kī
# 	a-li-bis-tic-ký
# aliterace a.li.te.ra.tse
# 	a-li-te-ra-ce
# alkalický al.ka.lits.kī
# 	al-ka-lic-ký
# alkaloid al.ka.lo.jit
# 	BREAKING! word: id, syllables: al-ka-lo-, pronounciation: jit
# 	Lengths do not match. Word: alkaloid, syllables: al-ka-lo-, pronounciation: al.ka.lo.jit (alkaloid)
# alkoholicky al.ko.ho.lits.ki
# 	al-ko-ho-lic-ky
# alkoholický al.ko.ho.lits.kī
# 	al-ko-ho-lic-ký
# alkoholička al.ko.ho.litš.ka
# 	al-ko-ho-lič-ka
# allegro a.le.gro
# 	BREAKING! word: egro, syllables: a-ll-, pronounciation: gro
# 	Lengths do not match. Word: allegro, syllables: a-ll-, pronounciation: a.le.gro (allegro)
# almanach al.ma.nax
# 	BREAKING! word: ch, syllables: al-ma-na, pronounciation: x
# 	Lengths do not match. Word: almanach, syllables: al-ma-na, pronounciation: al.ma.nax (almanach)
# alokace a.lo.ka.tse
# 	a-lo-ka-ce
# alokuce a.lo.ku.tse
# 	a-lo-ku-ce
# alou a.lö
# 	BREAKING! word: ou, syllables: a-l, pronounciation: ö
# 	Lengths do not match. Word: alou, syllables: a-l, pronounciation: a.lö (alou)
# altruismus al.tru.ji.zmus
# 	BREAKING! word: ismus, syllables: al-tru-, pronounciation: ji.zmus
# 	Lengths do not match. Word: altruismus, syllables: al-tru-, pronounciation: al.tru.ji.zmus (altruismus)
# altruista al.tru.jis.ta
# 	BREAKING! word: ista, syllables: al-tru-, pronounciation: jis.ta
# 	Lengths do not match. Word: altruista, syllables: al-tru-, pronounciation: al.tru.jis.ta (altruista)
# altruistický al.tru.jis.tits.kī
# 	BREAKING! word: istický, syllables: al-tru-, pronounciation: jis.tits.kī
# 	Lengths do not match. Word: altruistický, syllables: al-tru-, pronounciation: al.tru.jis.tits.kī (altruistický)
# altruistka al.tru.jis.tka
# 	BREAKING! word: istka, syllables: al-tru-, pronounciation: jis.tka
# 	Lengths do not match. Word: altruistka, syllables: al-tru-, pronounciation: al.tru.jis.tka (altruistka)
# altruizmus al.tru.ji.zmus
# 	BREAKING! word: izmus, syllables: al-tru-, pronounciation: ji.zmus
# 	Lengths do not match. Word: altruizmus, syllables: al-tru-, pronounciation: al.tru.ji.zmus (altruizmus)
# aluminiový a.lu.mi.ni.jo.vī
# 	a-lu-mi-ni-o-vý
# aluminium a.lu.mī.ni.jum
# 	a-lu-mi-ni-um
# ambice am.bi.tse
# 	am-bi-ce
# ambiciózní am.bi.tsi.jō.zňī
# 	BREAKING! word: ózní, syllables: am-bi-ci-, pronounciation: jō.zňī
# 	Lengths do not match. Word: ambiciózní, syllables: am-bi-ci-, pronounciation: am.bi.tsi.jō.zňī (ambiciózní)
# ambulance am.bu.lan.tse
# 	am-bu-lan-ce
# ambulanční am.bu.lan.tšňī
# 	am-bu-lan-ční
# ambulatorium am.bu.la.to.ri.jum
# 	am-bu-la-to-ri-um
# americký a.me.rits.kī
# 	a-me-ric-ký
# amerikanizace a.me.ri.ka.ni.za.tse
# 	a-me-ri-ka-ni-za-ce
# amnestie am.nes.ti.je
# 	am-nes-ti-e
# amoniak a.mo.ni.jak
# 	Nothing found. BREAKING! word: ak, syllables: a-mo-ni-, pronounciation: jak
# 	Lengths do not match. Word: amoniak, syllables: a-mo-ni-, pronounciation: a.mo.ni.jak (amoniak)
# amonium a.mo.ni.jum
# 	a-mo-ni-um
# amortizace a.mor.ti.za.tse
# 	a-mor-ti-za-ce
# amplion am.pli.jon
# 	am-pli-on
# amputace am.pu.ta.tse
# 	am-pu-ta-ce
# anachronismus a.na.xro.ni.zmus
# 	BREAKING! word: chronismus, syllables: a-na-, pronounciation: xro.ni.zmus
# 	Lengths do not match. Word: anachronismus, syllables: a-na-, pronounciation: a.na.xro.ni.zmus (anachronismus)
# anachronizmus a.na.xro.ni.zmus
# 	BREAKING! word: chronizmus, syllables: a-na-, pronounciation: xro.ni.zmus
# 	Lengths do not match. Word: anachronizmus, syllables: a-na-, pronounciation: a.na.xro.ni.zmus (anachronizmus)
# analogicky a.na.lo.gits.ki
# 	a-na-lo-gic-ky
# analogický a.na.lo.gits.kī
# 	a-na-lo-gic-ký
# analogičnost a.na.lo.gi.tšnost
# 	a-na-lo-gi-čnost
# analogie a.na.lo.gi.je
# 	a-na-lo-gi-e
# analyticky a.na.li.tits.ki
# 	a-na-ly-tic-ky
# analytický a.na.li.tits.kī
# 	a-na-ly-tic-ký
# analytičnost a.na.li.ti.tšnost
# 	a-na-ly-ti-čnost
# anarchismus a.nar.xi.zmus
# 	BREAKING! word: chismus, syllables: a-nar-, pronounciation: xi.zmus
# 	Lengths do not match. Word: anarchismus, syllables: a-nar-, pronounciation: a.nar.xi.zmus (anarchismus)
# anarchista a.nar.xis.ta
# 	BREAKING! word: chista, syllables: a-nar-, pronounciation: xis.ta
# 	Lengths do not match. Word: anarchista, syllables: a-nar-, pronounciation: a.nar.xis.ta (anarchista)
# anarchizmus a.nar.xi.zmus
# 	BREAKING! word: chizmus, syllables: a-nar-, pronounciation: xi.zmus
# 	Lengths do not match. Word: anarchizmus, syllables: a-nar-, pronounciation: a.nar.xi.zmus (anarchizmus)
# anatomicky a.na.to.mits.ki
# 	a-na-to-mic-ky
# anatomický a.na.to.mits.kī
# 	a-na-to-mic-ký
# anatomie a.na.to.mi.je
# 	a-na-to-mi-e
# andělíček an.ďe.lī.tšek
# 	Nothing found. BREAKING! word: dělíček, syllables: an-, pronounciation: ďe.lī.tšek
# 	Lengths do not match. Word: andělíček, syllables: an-, pronounciation: an.ďe.lī.tšek (andělíček)
# anekční a.nek.tšňī
# 	a-nek-ční
# anekdotický a.nek.do.tits.kī
# 	a-nek-do-tic-ký
# anemický a.ne.mits.kī
# 	a-ne-mic-ký
# anémie a.nē.mi.je
# 	a-né-mi-e
# aneroid a.ne.ro.jit
# 	BREAKING! word: id, syllables: a-ne-ro-, pronounciation: jit
# 	Lengths do not match. Word: aneroid, syllables: a-ne-ro-, pronounciation: a.ne.ro.jit (aneroid)
# anestezie a.nes.te.zi.je
# 	a-nes-te-zi-e
# anexe a.nek.se
# 	BREAKING! word: e, syllables: a-nex-, pronounciation: se
# 	Lengths do not match. Word: anexe, syllables: a-nex-, pronounciation: a.nek.se (anexe)
# anexní a.nek.sňī
# 	BREAKING! word: ní, syllables: a-nex-, pronounciation: sňī
# 	Lengths do not match. Word: anexní, syllables: a-nex-, pronounciation: a.nek.sňī (anexní)
# anglicky an.glits.ki
# 	an-glic-ky
# anglický an.glits.kī
# 	an-glic-ký
# angličtina an.glitš.ťi.na
# 	an-glič-ti-na
# angličtinář an.glitš.ťi.nāř
# 	an-glič-ti-nář
# angličtinářka an.glitš.ťi.nāř.ka
# 	an-glič-ti-nář-ka
# anglistický an.glis.tits.kī
# 	an-glis-tic-ký
# anion a.ni.jōn
# 	BREAKING! word: on, syllables: a-ni-, pronounciation: jōn
# 	Lengths do not match. Word: anion, syllables: a-ni-, pronounciation: a.ni.jōn (anion)
# aniont a.ni.jont
# 	a-ni-ont
# anomálie a.no.mā.li.je
# 	a-no-má-li-e
# anonce a.non.tse
# 	a-non-ce
# anorganický a.nor.ga.nits.kī
# 	a-nor-ga-nic-ký
# anotace a.no.ta.tse
# 	a-no-ta-ce
# antagonistický an.ta.go.nis.tits.kī
# 	an-ta-go-nis-tic-ký
# anténní an.tē.ňī
# 	BREAKING! word: ní, syllables: an-té-n, pronounciation: ī
# 	Lengths do not match. Word: anténní, syllables: an-té-n, pronounciation: an.tē.ňī (anténní)
# antibiotikum an.ti.bi.jo.ti.kum
# 	an-ti-bi-o-ti-kum
# anticipace an.ti.tsi.pa.tse
# 	an-ti-ci-pa-ce
# anticipovat an.ti.tsi.po.vat
# 	an-ti-ci-po-vat
# antický an.tits.kī
# 	an-tic-ký
# antičástice an.ti.tšās.ťi.tse
# 	an-ti-čás-ti-ce
# antidemokratický an.ti.de.mo.kra.tits.kī
# 	an-ti-de-mo-kra-tic-ký
# antifašistický an.ti.fa.šis.tits.kī
# 	an-ti-fa-šis-tic-ký
# antikoncepce an.ti.kon.tsep.tse
# 	an-ti-kon-cep-ce
# antikoncepční an.ti.kon.tsep.tšňī
# 	an-ti-kon-cep-ční
# antikvariát an.ti.kva.ri.jāt
# 	an-ti-kva-ri-át
# antimilitaristický an.ti.mi.li.ta.ris.tits.kī
# 	an-ti-mi-li-ta-ris-tic-ký
# antipatie an.ti.pa.ti.je
# 	an-ti-pa-ti-e
# antiseptický an.ti.sep.tits.kī
# 	an-ti-sep-tic-ký
# antitoxin an.ti.tok.sīn
# 	BREAKING! word: in, syllables: an-ti-tox-, pronounciation: sīn
# 	Lengths do not match. Word: antitoxin, syllables: an-ti-tox-, pronounciation: an.ti.tok.sīn (antitoxin)
# antologie an.to.lo.gi.je
# 	an-to-lo-gi-e
# antracit an.tra.tsit
# 	an-tra-cit
# antropologický an.tro.po.lo.gits.kī
# 	an-tro-po-lo-gic-ký
# antropologie an.tro.po.lo.gi.je
# 	an-tro-po-lo-gi-e
# anuita a.nu.ji.ta
# 	BREAKING! word: ita, syllables: a-nu-, pronounciation: ji.ta
# 	Lengths do not match. Word: anuita, syllables: a-nu-, pronounciation: a.nu.ji.ta (anuita)
# apaticky a.pa.tits.ki
# 	a-pa-tic-ky
# apatický a.pa.tits.kī
# 	a-pa-tic-ký
# apatičnost a.pa.ti.tšnost
# 	a-pa-ti-čnost
# apatie a.pa.ti.je
# 	a-pa-ti-e
# apendix a.pen.diks
# 	a-pen-dix
# aplaus a.pläs
# 	Nothing found. BREAKING! word: aus, syllables: a-pl, pronounciation: äs
# 	Lengths do not match. Word: aplaus, syllables: a-pl, pronounciation: a.pläs (aplaus)
# aplikace a.pli.ka.tse
# 	a-pli-ka-ce
# apodiktický a.po.dik.tits.kī
# 	a-po-dik-tic-ký
# apokalyptický a.po.ka.lip.tits.kī
# 	a-po-ka-lyp-tic-ký
# apolitický a.po.li.tits.kī
# 	a-po-li-tic-ký
# apolitičnost a.po.li.ti.tšnost
# 	a-po-li-ti-čnost
# apologie a.po.lo.gi.je
# 	a-po-lo-gi-e
# apozice a.po.zi.tse
# 	a-po-zi-ce
# apriorní a.pri.jor.ňī
# 	a-pri-or-ní
# aprobace a.pro.ba.tse
# 	a-pro-ba-ce
# aprobační a.pro.ba.tšňī
# 	a-pro-ba-ční
# arci ar.tsi
# 	ar-ci
# arcibiskup ar.tsi.bis.kup
# 	ar-ci-bis-kup
# arcibiskupský ar.tsi.bis.kup.skī
# 	ar-ci-bis-kup-ský
# arcibiskupství ar.tsi.bis.kups.tvī
# 	ar-ci-bis-kups-tví
# arcikníže ar.tsi.kňī.že
# 	ar-ci-kní-že
# arciknížecí ar.tsi.kňī.že.tsī
# 	ar-ci-kní-že-cí
# arciknížectví ar.tsi.kňī.žets.tvī
# 	ar-ci-kní-žec-tví
# arcivévoda ar.tsi.vē.vo.da
# 	ar-ci-vé-vo-da
# arcivévodský ar.tsi.vē.vots.kī
# 	ar-ci-vé-vods-ký
# arcivévodství ar.tsi.vē.vots.tvī
# 	ar-ci-vé-vods-tví
# argotický ar.go.tits.kī
# 	ar-go-tic-ký
# argumentace ar.gu.men.ta.tse
# 	ar-gu-men-ta-ce
# arch arx
# 	BREAKING! word: ch, syllables: ar, pronounciation: x
# 	Lengths do not match. Word: arch, syllables: ar, pronounciation: arx (arch)
# archa ar.xa
# 	BREAKING! word: cha, syllables: ar-, pronounciation: xa
# 	Lengths do not match. Word: archa, syllables: ar-, pronounciation: ar.xa (archa)
# archanděl ar.xan.ďel
# 	BREAKING! word: chanděl, syllables: ar-, pronounciation: xan.ďel
# 	Lengths do not match. Word: archanděl, syllables: ar-, pronounciation: ar.xan.ďel (archanděl)
# archeolog ar.xe.o.lok
# 	BREAKING! word: cheolog, syllables: ar-, pronounciation: xe.o.lok
# 	Lengths do not match. Word: archeolog, syllables: ar-, pronounciation: ar.xe.o.lok (archeolog)
# archeoložka ar.xe.o.loš.ka
# 	BREAKING! word: cheoložka, syllables: ar-, pronounciation: xe.o.loš.ka
# 	Lengths do not match. Word: archeoložka, syllables: ar-, pronounciation: ar.xe.o.loš.ka (archeoložka)
# architekt ar.xi.tekt
# 	BREAKING! word: chitekt, syllables: ar-, pronounciation: xi.tekt
# 	Lengths do not match. Word: architekt, syllables: ar-, pronounciation: ar.xi.tekt (architekt)
# architektka ar.xi.tek.tka
# 	BREAKING! word: chitektka, syllables: ar-, pronounciation: xi.tek.tka
# 	Lengths do not match. Word: architektka, syllables: ar-, pronounciation: ar.xi.tek.tka (architektka)
# architektonika ar.xi.tek.to.ni.ka
# 	BREAKING! word: chitektonika, syllables: ar-, pronounciation: xi.tek.to.ni.ka
# 	Lengths do not match. Word: architektonika, syllables: ar-, pronounciation: ar.xi.tek.to.ni.ka (architektonika)
# architektura ar.xi.tek.tū.ra
# 	BREAKING! word: chitektura, syllables: ar-, pronounciation: xi.tek.tū.ra
# 	Lengths do not match. Word: architektura, syllables: ar-, pronounciation: ar.xi.tek.tū.ra (architektura)
# archiv ar.xīf
# 	BREAKING! word: chiv, syllables: ar-, pronounciation: xīf
# 	Lengths do not match. Word: archiv, syllables: ar-, pronounciation: ar.xīf (archiv)
# archivář ar.xi.vāř
# 	BREAKING! word: chivář, syllables: ar-, pronounciation: xi.vāř
# 	Lengths do not match. Word: archivář, syllables: ar-, pronounciation: ar.xi.vāř (archivář)
# archivářka ar.xi.vāř.ka
# 	BREAKING! word: chivářka, syllables: ar-, pronounciation: xi.vāř.ka
# 	Lengths do not match. Word: archivářka, syllables: ar-, pronounciation: ar.xi.vāř.ka (archivářka)
# archivní ar.xī.vňī
# 	BREAKING! word: chivní, syllables: ar-, pronounciation: xī.vňī
# 	Lengths do not match. Word: archivní, syllables: ar-, pronounciation: ar.xī.vňī (archivní)
# árie ā.ri.je
# 	á-ri-e
# aristokracie a.ris.to.kra.tsi.je
# 	a-ris-to-kra-ci-e
# aristokraticky a.ris.to.kra.tits.ki
# 	a-ris-to-kra-tic-ky
# aristokratický a.ris.to.kra.tits.kī
# 	a-ris-to-kra-tic-ký
# aritmetický a.ri.tme.tits.kī
# 	a-ri-tme-tic-ký
# arogance a.ro.gan.tse
# 	a-ro-gan-ce
# aromatický a.ro.ma.tits.kī
# 	a-ro-ma-tic-ký
# arterie ar.te.ri.je
# 	ar-te-ri-e
# arterioskleróza ar.te.ri.jos.kle.rō.za
# 	ar-te-ri-os-kle-ró-za
# artikulace ar.ti.ku.la.tse
# 	ar-ti-ku-la-ce
# artikulační ar.ti.ku.la.tšňī
# 	ar-ti-ku-la-ční
# artilerie ar.ti.le.ri.je
# 	ar-ti-le-ri-e
# artistický ar.tis.tits.kī
# 	ar-tis-tic-ký
# asanace a.sa.na.tse
# 	a-sa-na-ce
# asanační a.sa.na.tšňī
# 	a-sa-na-ční
# asimilace a.si.mi.la.tse
# 	a-si-mi-la-ce
# asimilační a.si.mi.la.tšňī
# 	a-si-mi-la-ční
# asistence a.sis.ten.tse
# 	a-sis-ten-ce
# asketický as.ke.tits.kī
# 	as-ke-tic-ký
# asociace a.so.tsi.ja.tse
# 	Nothing found. BREAKING! word: ace, syllables: a-so-ci-, pronounciation: ja.tse
# 	Lengths do not match. Word: asociace, syllables: a-so-ci-, pronounciation: a.so.tsi.ja.tse (asociace)
# asociační a.so.tsi.ja.tšňī
# 	Nothing found. BREAKING! word: ační, syllables: a-so-ci-, pronounciation: ja.tšňī
# 	Lengths do not match. Word: asociační, syllables: a-so-ci-, pronounciation: a.so.tsi.ja.tšňī (asociační)
# asociál a.so.tsi.jāl
# 	a-so-ci-ál
# asociální a.so.tsi.jāl.ňī
# 	a-so-ci-ál-ní
# asonance a.so.nan.tse
# 	a-so-nan-ce
# aspirace as.pi.ra.tse
# 	as-pi-ra-ce
# astenický as.te.nits.kī
# 	as-te-nic-ký
# astmatický as.tma.tits.kī
# 	as-tma-tic-ký
# astmatička as.tma.titš.ka
# 	as-tma-tič-ka
# astrologický as.tro.lo.gits.kī
# 	as-tro-lo-gic-ký
# astrologie as.tro.lo.gi.je
# 	as-tro-lo-gi-e
# astronaut as.tro.nät
# 	Nothing found. BREAKING! word: aut, syllables: as-tro-n, pronounciation: ät
# 	Lengths do not match. Word: astronaut, syllables: as-tro-n, pronounciation: as.tro.nät (astronaut)
# astronautika as.tro.nä.ti.ka
# 	BREAKING! word: utika, syllables: as-tro-na-, pronounciation: ti.ka
# 	Lengths do not match. Word: astronautika, syllables: as-tro-na-, pronounciation: as.tro.nä.ti.ka (astronautika)
# astronomický as.tro.no.mits.kī
# 	as-tro-no-mic-ký
# astronomie as.tro.no.mi.je
# 	as-tro-no-mi-e
# asymetrický a.si.me.trits.kī
# 	a-sy-me-tric-ký
# asymetrie a.si.me.tri.je
# 	a-sy-me-tri-e
# ateismus a.te.ji.zmus
# 	BREAKING! word: ismus, syllables: a-te-, pronounciation: ji.zmus
# 	Lengths do not match. Word: ateismus, syllables: a-te-, pronounciation: a.te.ji.zmus (ateismus)
# ateista a.te.jis.ta
# 	BREAKING! word: ista, syllables: a-te-, pronounciation: jis.ta
# 	Lengths do not match. Word: ateista, syllables: a-te-, pronounciation: a.te.jis.ta (ateista)
# ateistický a.te.jis.tits.kī
# 	BREAKING! word: istický, syllables: a-te-, pronounciation: jis.tits.kī
# 	Lengths do not match. Word: ateistický, syllables: a-te-, pronounciation: a.te.jis.tits.kī (ateistický)
# ateistka a.te.jis.tka
# 	BREAKING! word: istka, syllables: a-te-, pronounciation: jis.tka
# 	Lengths do not match. Word: ateistka, syllables: a-te-, pronounciation: a.te.jis.tka (ateistka)
# ateizmus a.te.ji.zmus
# 	BREAKING! word: izmus, syllables: a-te-, pronounciation: ji.zmus
# 	Lengths do not match. Word: ateizmus, syllables: a-te-, pronounciation: a.te.ji.zmus (ateizmus)
# ateliér a.te.li.jēr
# 	a-te-li-ér
# ateliérový a.te.li.jē.ro.vī
# 	a-te-li-é-ro-vý
# atestace a.tes.ta.tse
# 	a-tes-ta-ce
# atestační a.tes.ta.tšňī
# 	a-tes-ta-ční
# atleticky a.tle.tits.ki
# 	a-tle-tic-ky
# atletický a.tle.tits.kī
# 	a-tle-tic-ký
# atmosférický a.tmos.fē.rits.kī
# 	a-tmos-fé-ric-ký
# atomizace a.to.mi.za.tse
# 	a-to-mi-za-ce
# atrakce a.trak.tse
# 	a-trak-ce
# atriový a.tri.jo.vī
# 	a-tri-o-vý
# atrium ā.tri.jum
# 	a-tri-um
# atypicky a.ti.pits.ki
# 	a-ty-pic-ky
# atypický a.ti.pits.kī
# 	a-ty-pic-ký
# au ä
# 	Nothing found. BREAKING! word: au, syllables: , pronounciation: ä
# 	Lengths do not match. Word: au, syllables: , pronounciation: ä (au)
# audience ä.di.jen.tse
# 	BREAKING! word: udience, syllables: a-, pronounciation: di.jen.tse
# 	Lengths do not match. Word: audience, syllables: a-, pronounciation: ä.di.jen.tse (audience)
# audienční ä.di.jen.tšňī
# 	BREAKING! word: udienční, syllables: a-, pronounciation: di.jen.tšňī
# 	Lengths do not match. Word: audienční, syllables: a-, pronounciation: ä.di.jen.tšňī (audienční)
# auditivní ä.di.tī.vňī
# 	BREAKING! word: uditivní, syllables: a-, pronounciation: di.tī.vňī
# 	Lengths do not match. Word: auditivní, syllables: a-, pronounciation: ä.di.tī.vňī (auditivní)
# august ä.gust
# 	BREAKING! word: ugust, syllables: a-, pronounciation: gust
# 	Lengths do not match. Word: august, syllables: a-, pronounciation: ä.gust (august)
# aula ä.la
# 	BREAKING! word: ula, syllables: a-, pronounciation: la
# 	Lengths do not match. Word: aula, syllables: a-, pronounciation: ä.la (aula)
# aureola ä.re.o.la
# 	BREAKING! word: ureola, syllables: a-, pronounciation: re.o.la
# 	Lengths do not match. Word: aureola, syllables: a-, pronounciation: ä.re.o.la (aureola)
# aut ät
# 	Nothing found. BREAKING! word: aut, syllables: , pronounciation: ät
# 	Lengths do not match. Word: aut, syllables: , pronounciation: ät (aut)
# auto ä.to
# 	BREAKING! word: uto, syllables: a-, pronounciation: to
# 	Lengths do not match. Word: auto, syllables: a-, pronounciation: ä.to (auto)
# autobiografický ä.to.bi.jo.gra.fits.kī
# 	BREAKING! word: utobiografický, syllables: a-, pronounciation: to.bi.jo.gra.fits.kī
# 	Lengths do not match. Word: autobiografický, syllables: a-, pronounciation: ä.to.bi.jo.gra.fits.kī (autobiografický)
# autobiografie ä.to.bi.jo.gra.fi.je
# 	BREAKING! word: utobiografie, syllables: a-, pronounciation: to.bi.jo.gra.fi.je
# 	Lengths do not match. Word: autobiografie, syllables: a-, pronounciation: ä.to.bi.jo.gra.fi.je (autobiografie)
# autobus ä.to.bus
# 	BREAKING! word: utobus, syllables: a-, pronounciation: to.bus
# 	Lengths do not match. Word: autobus, syllables: a-, pronounciation: ä.to.bus (autobus)
# autobusový ä.to.bu.so.vī
# 	BREAKING! word: utobusový, syllables: a-, pronounciation: to.bu.so.vī
# 	Lengths do not match. Word: autobusový, syllables: a-, pronounciation: ä.to.bu.so.vī (autobusový)
# autodílna ä.to.ďīl.na
# 	BREAKING! word: utodílna, syllables: a-, pronounciation: to.ďīl.na
# 	Lengths do not match. Word: autodílna, syllables: a-, pronounciation: ä.to.ďīl.na (autodílna)
# autodrom ä.to.drom
# 	BREAKING! word: utodrom, syllables: a-, pronounciation: to.drom
# 	Lengths do not match. Word: autodrom, syllables: a-, pronounciation: ä.to.drom (autodrom)
# autogen ä.to.gēn
# 	BREAKING! word: utogen, syllables: a-, pronounciation: to.gēn
# 	Lengths do not match. Word: autogen, syllables: a-, pronounciation: ä.to.gēn (autogen)
# autogenní ä.to.ge.ňī
# 	BREAKING! word: utogenní, syllables: a-, pronounciation: to.ge.ňī
# 	Lengths do not match. Word: autogenní, syllables: a-, pronounciation: ä.to.ge.ňī (autogenní)
# autogram ä.to.gram
# 	BREAKING! word: utogram, syllables: a-, pronounciation: to.gram
# 	Lengths do not match. Word: autogram, syllables: a-, pronounciation: ä.to.gram (autogram)
# autojeřáb ä.to.je.řāp
# 	BREAKING! word: utojeřáb, syllables: a-, pronounciation: to.je.řāp
# 	Lengths do not match. Word: autojeřáb, syllables: a-, pronounciation: ä.to.je.řāp (autojeřáb)
# autokar ä.to.kar
# 	BREAKING! word: utokar, syllables: a-, pronounciation: to.kar
# 	Lengths do not match. Word: autokar, syllables: a-, pronounciation: ä.to.kar (autokar)
# autokempink ä.to.kem.pink
# 	BREAKING! word: utokempink, syllables: a-, pronounciation: to.kem.pink
# 	Lengths do not match. Word: autokempink, syllables: a-, pronounciation: ä.to.kem.pink (autokempink)
# autokosmetika ä.to.ko.sme.ti.ka
# 	BREAKING! word: utokosmetika, syllables: a-, pronounciation: to.ko.sme.ti.ka
# 	Lengths do not match. Word: autokosmetika, syllables: a-, pronounciation: ä.to.ko.sme.ti.ka (autokosmetika)
# automapa ä.to.ma.pa
# 	BREAKING! word: utomapa, syllables: a-, pronounciation: to.ma.pa
# 	Lengths do not match. Word: automapa, syllables: a-, pronounciation: ä.to.ma.pa (automapa)
# automat ä.to.mat
# 	BREAKING! word: utomat, syllables: a-, pronounciation: to.mat
# 	Lengths do not match. Word: automat, syllables: a-, pronounciation: ä.to.mat (automat)
# automatika ä.to.ma.ti.ka
# 	BREAKING! word: utomatika, syllables: a-, pronounciation: to.ma.ti.ka
# 	Lengths do not match. Word: automatika, syllables: a-, pronounciation: ä.to.ma.ti.ka (automatika)
# automatizovaný ä.to.ma.ti.zo.va.nī
# 	BREAKING! word: utomatizovaný, syllables: a-, pronounciation: to.ma.ti.zo.va.nī
# 	Lengths do not match. Word: automatizovaný, syllables: a-, pronounciation: ä.to.ma.ti.zo.va.nī (automatizovaný)
# automatizovat ä.to.ma.ti.zo.vat
# 	BREAKING! word: utomatizovat, syllables: a-, pronounciation: to.ma.ti.zo.vat
# 	Lengths do not match. Word: automatizovat, syllables: a-, pronounciation: ä.to.ma.ti.zo.vat (automatizovat)
# automechanický ä.to.me.xa.nits.kī
# 	BREAKING! word: utomechanický, syllables: a-, pronounciation: to.me.xa.nits.kī
# 	Lengths do not match. Word: automechanický, syllables: a-, pronounciation: ä.to.me.xa.nits.kī (automechanický)
# automechanik ä.to.me.xa.nik
# 	BREAKING! word: utomechanik, syllables: a-, pronounciation: to.me.xa.nik
# 	Lengths do not match. Word: automechanik, syllables: a-, pronounciation: ä.to.me.xa.nik (automechanik)
# automobil ä.to.mo.bil
# 	BREAKING! word: utomobil, syllables: a-, pronounciation: to.mo.bil
# 	Lengths do not match. Word: automobil, syllables: a-, pronounciation: ä.to.mo.bil (automobil)
# automobilismus ä.to.mo.bi.li.zmus
# 	BREAKING! word: utomobilismus, syllables: a-, pronounciation: to.mo.bi.li.zmus
# 	Lengths do not match. Word: automobilismus, syllables: a-, pronounciation: ä.to.mo.bi.li.zmus (automobilismus)
# automobilista ä.to.mo.bi.lis.ta
# 	BREAKING! word: utomobilista, syllables: a-, pronounciation: to.mo.bi.lis.ta
# 	Lengths do not match. Word: automobilista, syllables: a-, pronounciation: ä.to.mo.bi.lis.ta (automobilista)
# automobilistka ä.to.mo.bi.lis.tka
# 	BREAKING! word: utomobilistka, syllables: a-, pronounciation: to.mo.bi.lis.tka
# 	Lengths do not match. Word: automobilistka, syllables: a-, pronounciation: ä.to.mo.bi.lis.tka (automobilistka)
# automobilizmus ä.to.mo.bi.li.zmus
# 	BREAKING! word: utomobilizmus, syllables: a-, pronounciation: to.mo.bi.li.zmus
# 	Lengths do not match. Word: automobilizmus, syllables: a-, pronounciation: ä.to.mo.bi.li.zmus (automobilizmus)
# automobilka ä.to.mo.bil.ka
# 	BREAKING! word: utomobilka, syllables: a-, pronounciation: to.mo.bil.ka
# 	Lengths do not match. Word: automobilka, syllables: a-, pronounciation: ä.to.mo.bil.ka (automobilka)
# automobilový ä.to.mo.bi.lo.vī
# 	BREAKING! word: utomobilový, syllables: a-, pronounciation: to.mo.bi.lo.vī
# 	Lengths do not match. Word: automobilový, syllables: a-, pronounciation: ä.to.mo.bi.lo.vī (automobilový)
# automotoklub ä.to.mo.to.klup
# 	BREAKING! word: utomotoklub, syllables: a-, pronounciation: to.mo.to.klup
# 	Lengths do not match. Word: automotoklub, syllables: a-, pronounciation: ä.to.mo.to.klup (automotoklub)
# autonomní ä.to.nom.ňī
# 	BREAKING! word: utonomní, syllables: a-, pronounciation: to.nom.ňī
# 	Lengths do not match. Word: autonomní, syllables: a-, pronounciation: ä.to.nom.ňī (autonomní)
# autoportrét ä.to.por.trēt
# 	BREAKING! word: utoportrét, syllables: a-, pronounciation: to.por.trēt
# 	Lengths do not match. Word: autoportrét, syllables: a-, pronounciation: ä.to.por.trēt (autoportrét)
# autopříslušenství ä.to.přī.slu.šens.tvī
# 	BREAKING! word: utopříslušenství, syllables: a-, pronounciation: to.přī.slu.šens.tvī
# 	Lengths do not match. Word: autopříslušenství, syllables: a-, pronounciation: ä.to.přī.slu.šens.tvī (autopříslušenství)
# autor ä.tor
# 	BREAKING! word: utor, syllables: a-, pronounciation: tor
# 	Lengths do not match. Word: autor, syllables: a-, pronounciation: ä.tor (autor)
# autorita ä.to.ri.ta
# 	BREAKING! word: utorita, syllables: a-, pronounciation: to.ri.ta
# 	Lengths do not match. Word: autorita, syllables: a-, pronounciation: ä.to.ri.ta (autorita)
# autoritář ä.to.ri.tāř
# 	BREAKING! word: utoritář, syllables: a-, pronounciation: to.ri.tāř
# 	Lengths do not match. Word: autoritář, syllables: a-, pronounciation: ä.to.ri.tāř (autoritář)
# autoritativně ä.to.ri.ta.ti.vňe
# 	BREAKING! word: utoritativně, syllables: a-, pronounciation: to.ri.ta.ti.vňe
# 	Lengths do not match. Word: autoritativně, syllables: a-, pronounciation: ä.to.ri.ta.ti.vňe (autoritativně)
# autoritativní ä.to.ri.ta.tī.vňī
# 	BREAKING! word: utoritativní, syllables: a-, pronounciation: to.ri.ta.tī.vňī
# 	Lengths do not match. Word: autoritativní, syllables: a-, pronounciation: ä.to.ri.ta.tī.vňī (autoritativní)
# autoritativnost ä.to.ri.ta.ti.vnost
# 	BREAKING! word: utoritativnost, syllables: a-, pronounciation: to.ri.ta.ti.vnost
# 	Lengths do not match. Word: autoritativnost, syllables: a-, pronounciation: ä.to.ri.ta.ti.vnost (autoritativnost)
# autorka ä.tor.ka
# 	BREAKING! word: utorka, syllables: a-, pronounciation: tor.ka
# 	Lengths do not match. Word: autorka, syllables: a-, pronounciation: ä.tor.ka (autorka)
# autorský ä.tor.skī
# 	BREAKING! word: utorský, syllables: a-, pronounciation: tor.skī
# 	Lengths do not match. Word: autorský, syllables: a-, pronounciation: ä.tor.skī (autorský)
# autorství ä.tors.tvī
# 	BREAKING! word: utorství, syllables: a-, pronounciation: tors.tvī
# 	Lengths do not match. Word: autorství, syllables: a-, pronounciation: ä.tors.tvī (autorství)
# autosalon ä.to.sa.lon
# 	BREAKING! word: utosalon, syllables: a-, pronounciation: to.sa.lon
# 	Lengths do not match. Word: autosalon, syllables: a-, pronounciation: ä.to.sa.lon (autosalon)
# autostop ä.tos.top
# 	BREAKING! word: utostop, syllables: a-, pronounciation: tos.top
# 	Lengths do not match. Word: autostop, syllables: a-, pronounciation: ä.tos.top (autostop)
# autostráda ä.tos.trā.da
# 	BREAKING! word: utostráda, syllables: a-, pronounciation: tos.trā.da
# 	Lengths do not match. Word: autostráda, syllables: a-, pronounciation: ä.tos.trā.da (autostráda)
# autoškola ä.toš.ko.la
# 	BREAKING! word: utoškola, syllables: a-, pronounciation: toš.ko.la
# 	Lengths do not match. Word: autoškola, syllables: a-, pronounciation: ä.toš.ko.la (autoškola)
# autoturistika ä.to.tu.ris.ti.ka
# 	BREAKING! word: utoturistika, syllables: a-, pronounciation: to.tu.ris.ti.ka
# 	Lengths do not match. Word: autoturistika, syllables: a-, pronounciation: ä.to.tu.ris.ti.ka (autoturistika)
# autový ä.to.vī
# 	BREAKING! word: utový, syllables: a-, pronounciation: to.vī
# 	Lengths do not match. Word: autový, syllables: a-, pronounciation: ä.to.vī (autový)
# aviatik a.vi.ja.tik
# 	Nothing found. BREAKING! word: atik, syllables: a-vi-, pronounciation: ja.tik
# 	Lengths do not match. Word: aviatik, syllables: a-vi-, pronounciation: a.vi.ja.tik (aviatik)
# aviatika a.vi.ja.ti.ka
# 	Nothing found. BREAKING! word: atika, syllables: a-vi-, pronounciation: ja.ti.ka
# 	Lengths do not match. Word: aviatika, syllables: a-vi-, pronounciation: a.vi.ja.ti.ka (aviatika)
# axiologie ak.si.jo.lo.gi.je
# 	BREAKING! word: iologie, syllables: ax-, pronounciation: si.jo.lo.gi.je
# 	Lengths do not match. Word: axiologie, syllables: ax-, pronounciation: ak.si.jo.lo.gi.je (axiologie)
# axiom ak.si.jom
# 	BREAKING! word: iom, syllables: ax-, pronounciation: si.jom
# 	Lengths do not match. Word: axiom, syllables: ax-, pronounciation: ak.si.jom (axiom)
# axiomatický ak.si.jo.ma.tits.kī
# 	BREAKING! word: iomatický, syllables: ax-, pronounciation: si.jo.ma.tits.kī
# 	Lengths do not match. Word: axiomatický, syllables: ax-, pronounciation: ak.si.jo.ma.tits.kī (axiomatický)
# axiomatizace ak.si.jo.ma.ti.za.tse
# 	BREAKING! word: iomatizace, syllables: ax-, pronounciation: si.jo.ma.ti.za.tse
# 	Lengths do not match. Word: axiomatizace, syllables: ax-, pronounciation: ak.si.jo.ma.ti.za.tse (axiomatizace)
# babička ba.bitš.ka
# 	ba-bič-ka
# babičkovský ba.bitš.kof.skī
# 	ba-bič-kov-ský
# babočka ba.botš.ka
# 	ba-boč-ka
# bábovička bā.bo.vitš.ka
# 	bá-bo-vič-ka
# baby bej.bi
# 	Nothing found. BREAKING! word: aby, syllables: b, pronounciation: ej.bi
# 	Lengths do not match. Word: baby, syllables: b, pronounciation: bej.bi (baby)
# bác bāts
# 	bác
# bacat ba.tsat
# 	ba-cat
# bacil ba.tsil
# 	ba-cil
# bacilonosič ba.tsi.lo.no.sitš
# 	ba-ci-lo-no-sič
# bacilonosička ba.tsi.lo.no.sitš.ka
# 	ba-ci-lo-no-sič-ka
# bacilonosičství ba.tsi.lo.no.sitš.stvī
# 	ba-ci-lo-no-sič-ství
# bacit ba.tsit
# 	ba-cit
# baculatý ba.tsu.la.tī
# 	ba-cu-la-tý
# bača ba.tša
# 	ba-ča
# bačkora batš.ko.ra
# 	bač-ko-ra
# bačkorka batš.kor.ka
# 	bač-kor-ka
# bačkůrka batš.kūr.ka
# 	bač-kůr-ka
# bafnout ba.fnöt
# 	BREAKING! word: out, syllables: ba-fn, pronounciation: öt
# 	Lengths do not match. Word: bafnout, syllables: ba-fn, pronounciation: ba.fnöt (bafnout)
# bagatelizace ba.ga.te.li.za.tse
# 	ba-ga-te-li-za-ce
# bahenní ba.he.ňī
# 	BREAKING! word: ní, syllables: ba-he-n, pronounciation: ī
# 	Lengths do not match. Word: bahenní, syllables: ba-he-n, pronounciation: ba.he.ňī (bahenní)
# bach bax
# 	BREAKING! word: ch, syllables: ba, pronounciation: x
# 	Lengths do not match. Word: bach, syllables: ba, pronounciation: bax (bach)
# bachor ba.xor
# 	BREAKING! word: chor, syllables: ba-, pronounciation: xor
# 	Lengths do not match. Word: bachor, syllables: ba-, pronounciation: ba.xor (bachor)
# báchorka bā.xor.ka
# 	BREAKING! word: chorka, syllables: bá-, pronounciation: xor.ka
# 	Lengths do not match. Word: báchorka, syllables: bá-, pronounciation: bā.xor.ka (báchorka)
# bachratět ba.xra.ťet
# 	BREAKING! word: chratět, syllables: ba-, pronounciation: xra.ťet
# 	Lengths do not match. Word: bachratět, syllables: ba-, pronounciation: ba.xra.ťet (bachratět)
# bachratý ba.xra.tī
# 	BREAKING! word: chratý, syllables: ba-, pronounciation: xra.tī
# 	Lengths do not match. Word: bachratý, syllables: ba-, pronounciation: ba.xra.tī (bachratý)
# baissa bē.sa
# 	BREAKING! word: issa, syllables: ba-, pronounciation: sa
# 	Lengths do not match. Word: baissa, syllables: ba-, pronounciation: bē.sa (baissa)
# baisse bēs
# 	Nothing found. BREAKING! word: aisse, syllables: b, pronounciation: ēs
# 	Lengths do not match. Word: baisse, syllables: b, pronounciation: bēs (baisse)
# báječně bā.je.tšňe
# 	BREAKING! word: ě, syllables: bá-je-čn, pronounciation: e
# 	Lengths do not match. Word: báječně, syllables: bá-je-čn, pronounciation: bā.je.tšňe (báječně)
# báječný bā.je.tšnī
# 	bá-je-čný
# bakteriální bak.te.ri.jāl.ňī
# 	bak-te-ri-ál-ní
# bakterie bak.te.ri.je
# 	bak-te-ri-e
# bakteriologický bak.te.ri.jo.lo.gits.kī
# 	bak-te-ri-o-lo-gic-ký
# bakteriologie bak.te.ri.jo.lo.gi.je
# 	bak-te-ri-o-lo-gi-e
# baladicky ba.la.dits.ki
# 	ba-la-dic-ky
# baladický ba.la.dits.kī
# 	ba-la-dic-ký
# balancovat ba.lan.tso.vat
# 	ba-lan-co-vat
# baldachýn bal.da.xīn
# 	BREAKING! word: chýn, syllables: bal-da-, pronounciation: xīn
# 	Lengths do not match. Word: baldachýn, syllables: bal-da-, pronounciation: bal.da.xīn (baldachýn)
# balicí ba.li.tsī
# 	ba-li-cí
# balíček ba.lī.tšek
# 	ba-lí-ček
# balistický ba.lis.tits.kī
# 	ba-lis-tic-ký
# baptistický bap.tis.tits.kī
# 	bap-tis-tic-ký
# baráček ba.rā.tšek
# 	ba-rá-ček
# baráčník ba.rā.tšňīk
# 	ba-rá-čník
# barchet bar.xet
# 	BREAKING! word: chet, syllables: bar-, pronounciation: xet
# 	Lengths do not match. Word: barchet, syllables: bar-, pronounciation: bar.xet (barchet)
# barchetový bar.xe.to.vī
# 	BREAKING! word: chetový, syllables: bar-, pronounciation: xe.to.vī
# 	Lengths do not match. Word: barchetový, syllables: bar-, pronounciation: bar.xe.to.vī (barchetový)
# bariéra ba.ri.jē.ra
# 	ba-ri-é-ra
# barometrický ba.ro.me.trits.kī
# 	ba-ro-me-tric-ký
# barvicí bar.vi.tsī
# 	bar-vi-cí
# barvička bar.vitš.ka
# 	bar-vič-ka
# baskičtina bas.kitš.ťi.na
# 	bas-kič-ti-na
# básnický bā.sňits.kī
# 	bá-snic-ký
# básnictví bā.sňits.tvī
# 	bá-snic-tví
# básnička bā.sňitš.ka
# 	bá-snič-ka
# batalion ba.ta.li.jon
# 	ba-ta-li-on
# baterie ba.te.ri.je
# 	ba-te-ri-e
# bateriový ba.te.ri.jo.vī
# 	ba-te-ri-o-vý
# bázlivě bā.zli.vje
# 	bá-zli-vě
# bázlivec bā.zli.vets
# 	bá-zli-vec
# beat bīt
# 	BREAKING! word: eat, syllables: b, pronounciation: īt
# 	Lengths do not match. Word: beat, syllables: b, pronounciation: bīt (beat)
# beatnik bī.tňik
# 	Nothing found. BREAKING! word: atnik, syllables: be-, pronounciation: tňik
# 	Lengths do not match. Word: beatnik, syllables: be-, pronounciation: bī.tňik (beatnik)
# beatový bī.to.vī
# 	Nothing found. BREAKING! word: atový, syllables: be-, pronounciation: to.vī
# 	Lengths do not match. Word: beatový, syllables: be-, pronounciation: bī.to.vī (beatový)
# bebíčko be.bītš.ko
# 	be-bíč-ko
# bečet be.tšet
# 	be-čet
# bečka betš.ka
# 	beč-ka
# béčko bētš.ko
# 	béč-ko
# běda bje.da
# 	bě-da
# bedlivě be.dli.vje
# 	be-dli-vě
# bednička be.dňitš.ka
# 	be-dnič-ka
# bědovat bje.do.vat
# 	bě-do-vat
# beduín be.du.jīn
# 	BREAKING! word: ín, syllables: be-du-, pronounciation: jīn
# 	Lengths do not match. Word: beduín, syllables: be-du-, pronounciation: be.du.jīn (beduín)
# begonie be.go.ni.je
# 	be-go-ni-e
# běh bjex
# 	Nothing found. BREAKING! word: h, syllables: bě, pronounciation: x
# 	Lengths do not match. Word: běh, syllables: bě, pronounciation: bjex (běh)
# běhání bje.hā.ňī
# 	bě-há-ní
# běhat bje.hat
# 	bě-hat
# běhávat bje.hā.vat
# 	bě-há-vat
# během bje.hem
# 	bě-hem
# becherovka be.xe.rof.ka
# 	BREAKING! word: cherovka, syllables: be-, pronounciation: xe.rof.ka
# 	Lengths do not match. Word: becherovka, syllables: be-, pronounciation: be.xe.rof.ka (becherovka)
# bělásek bje.lā.sek
# 	bě-lá-sek
# bělat bje.lat
# 	bě-lat
# bělavý bje.la.vī
# 	bě-la-vý
# beletrie be.le.tri.je
# 	be-le-tri-e
# beletristický be.le.tris.tits.kī
# 	be-le-tris-tic-ký
# belhavě bel.ha.vje
# 	bel-ha-vě
# bělice bje.li.tse
# 	bě-li-ce
# bělicí bje.li.tsī
# 	bě-li-cí
# bělidlo bje.li.dlo
# 	bě-li-dlo
# bělit bje.lit
# 	bě-lit
# bělmo bjel.mo
# 	běl-mo
# bělo bje.lo
# 	bě-lo
# bělogvardějec bje.lo.gvar.ďe.jets
# 	Nothing found. BREAKING! word: dějec, syllables: bě-lo-gvar-, pronounciation: ďe.jets
# 	Lengths do not match. Word: bělogvardějec, syllables: bě-lo-gvar-, pronounciation: bje.lo.gvar.ďe.jets (bělogvardějec)
# bělogvardějský bje.lo.gvar.ďej.skī
# 	Nothing found. BREAKING! word: dějský, syllables: bě-lo-gvar-, pronounciation: ďej.skī
# 	Lengths do not match. Word: bělogvardějský, syllables: bě-lo-gvar-, pronounciation: bje.lo.gvar.ďej.skī (bělogvardějský)
# bělohlavý bje.lo.hla.vī
# 	bě-lo-hla-vý
# bělohorský bje.lo.hor.skī
# 	bě-lo-hor-ský
# běloruština bje.lo.ruš.ťi.na
# 	bě-lo-ruš-ti-na
# běloskvoucí bje.los.kvö.tsī
# 	BREAKING! word: ucí, syllables: bě-los-kvo-, pronounciation: tsī
# 	Lengths do not match. Word: běloskvoucí, syllables: bě-los-kvo-, pronounciation: bje.los.kvö.tsī (běloskvoucí)
# bělost bje.lost
# 	bě-lost
# bělostný bje.los.tnī
# 	bě-los-tný
# běloška bje.loš.ka
# 	bě-loš-ka
# bělošský bje.loš.skī
# 	bě-loš-ský
# běloučký bje.lötš.kī
# 	BREAKING! word: oučký, syllables: bě-l, pronounciation: ötš.kī
# 	Lengths do not match. Word: běloučký, syllables: bě-l, pronounciation: bje.lötš.kī (běloučký)
# bělovlasý bje.lo.vla.sī
# 	bě-lo-vla-sý
# benevolence be.ne.vo.len.tse
# 	be-ne-vo-len-ce
# beránčí be.rān.tšī
# 	be-rán-čí
# beranice be.ra.ňi.tse
# 	be-ra-ni-ce
# bércový bēr.tso.vī
# 	bér-co-vý
# bérec bē.rets
# 	bé-rec
# berlička ber.litš.ka
# 	ber-lič-ka
# běsnění bje.sňe.ňī
# 	bě-sně-ní
# běsnit bje.sňit
# 	bě-snit
# bestialita bes.ti.ja.li.ta
# 	Nothing found. BREAKING! word: alita, syllables: bes-ti-, pronounciation: ja.li.ta
# 	Lengths do not match. Word: bestialita, syllables: bes-ti-, pronounciation: bes.ti.ja.li.ta (bestialita)
# bestiálně bes.ti.jāl.ňe
# 	BREAKING! word: ě, syllables: bes-ti-ál-n, pronounciation: e
# 	Lengths do not match. Word: bestiálně, syllables: bes-ti-ál-n, pronounciation: bes.ti.jāl.ňe (bestiálně)
# bestiální bes.ti.jāl.ňī
# 	bes-ti-ál-ní
# bestiálnost bes.ti.jāl.nost
# 	bes-ti-ál-nost
# bestie bes.ti.je
# 	bes-ti-e
# bestseller bes.tse.ler
# 	Nothing found. BREAKING! word: ler, syllables: bes-tse-l, pronounciation: er
# 	Lengths do not match. Word: bestseller, syllables: bes-tse-l, pronounciation: bes.tse.ler (bestseller)
# bezbariérový bes.ba.ri.jē.ro.vī
# 	bez-ba-ri-é-ro-vý
# bezbarvě bes.bar.vje
# 	bez-bar-vě
# bezbranně bes.bra.ňe
# 	BREAKING! word: ně, syllables: bez-bra-n, pronounciation: e
# 	Lengths do not match. Word: bezbranně, syllables: bez-bra-n, pronounciation: bes.bra.ňe (bezbranně)
# bezbrannost bes.bra.nost
# 	BREAKING! word: nost, syllables: bez-bra-n, pronounciation: ost
# 	Lengths do not match. Word: bezbrannost, syllables: bez-bra-n, pronounciation: bes.bra.nost (bezbrannost)
# bezbranný bes.bra.nī
# 	BREAKING! word: ný, syllables: bez-bra-n, pronounciation: ī
# 	Lengths do not match. Word: bezbranný, syllables: bez-bra-n, pronounciation: bes.bra.nī (bezbranný)
# bezcitně bes.tsi.tňe
# 	BREAKING! word: ě, syllables: bez-ci-tn, pronounciation: e
# 	Lengths do not match. Word: bezcitně, syllables: bez-ci-tn, pronounciation: bes.tsi.tňe (bezcitně)
# bezcitnost bes.tsi.tnost
# 	bez-ci-tnost
# bezcitný bes.tsi.tnī
# 	bez-ci-tný
# bezděčně bes.ďe.tšňe
# 	Nothing found. BREAKING! word: děčně, syllables: bez-, pronounciation: ďe.tšňe
# 	Lengths do not match. Word: bezděčně, syllables: bez-, pronounciation: bes.ďe.tšňe (bezděčně)
# bezděčnost bes.ďe.tšnost
# 	Nothing found. BREAKING! word: děčnost, syllables: bez-, pronounciation: ďe.tšnost
# 	Lengths do not match. Word: bezděčnost, syllables: bez-, pronounciation: bes.ďe.tšnost (bezděčnost)
# bezděčný bes.ďe.tšnī
# 	Nothing found. BREAKING! word: děčný, syllables: bez-, pronounciation: ďe.tšnī
# 	Lengths do not match. Word: bezděčný, syllables: bez-, pronounciation: bes.ďe.tšnī (bezděčný)
# bezdomovec bes.do.mo.vets
# 	bez-do-mo-vec
# bezduchost bes.du.xost
# 	BREAKING! word: chost, syllables: bez-du-, pronounciation: xost
# 	Lengths do not match. Word: bezduchost, syllables: bez-du-, pronounciation: bes.du.xost (bezduchost)
# bezduchý bes.du.xī
# 	BREAKING! word: chý, syllables: bez-du-, pronounciation: xī
# 	Lengths do not match. Word: bezduchý, syllables: bez-du-, pronounciation: bes.du.xī (bezduchý)
# bezectně be.zets.tňe
# 	BREAKING! word: ě, syllables: be-zec-tn, pronounciation: e
# 	Lengths do not match. Word: bezectně, syllables: be-zec-tn, pronounciation: be.zets.tňe (bezectně)
# bezectnost be.zets.tnost
# 	be-zec-tnost
# bezectný be.zets.tnī
# 	be-zec-tný
# bezejmenně be.zej.me.ňe
# 	BREAKING! word: ně, syllables: be-zej-me-n, pronounciation: e
# 	Lengths do not match. Word: bezejmenně, syllables: be-zej-me-n, pronounciation: be.zej.me.ňe (bezejmenně)
# bezejmennost be.zej.me.nost
# 	BREAKING! word: nost, syllables: be-zej-me-n, pronounciation: ost
# 	Lengths do not match. Word: bezejmennost, syllables: be-zej-me-n, pronounciation: be.zej.me.nost (bezejmennost)
# bezejmenný be.zej.me.nī
# 	BREAKING! word: ný, syllables: be-zej-me-n, pronounciation: ī
# 	Lengths do not match. Word: bezejmenný, syllables: be-zej-me-n, pronounciation: be.zej.me.nī (bezejmenný)
# bezhlavě bes.hla.vje
# 	bez-hla-vě
# bezcharakterně bes.xa.rak.ter.ňe
# 	BREAKING! word: charakterně, syllables: bez-, pronounciation: xa.rak.ter.ňe
# 	Lengths do not match. Word: bezcharakterně, syllables: bez-, pronounciation: bes.xa.rak.ter.ňe (bezcharakterně)
# bezcharakterní bes.xa.rak.ter.ňī
# 	BREAKING! word: charakterní, syllables: bez-, pronounciation: xa.rak.ter.ňī
# 	Lengths do not match. Word: bezcharakterní, syllables: bez-, pronounciation: bes.xa.rak.ter.ňī (bezcharakterní)
# bezcharakternost bes.xa.rak.ter.nost
# 	BREAKING! word: charakternost, syllables: bez-, pronounciation: xa.rak.ter.nost
# 	Lengths do not match. Word: bezcharakternost, syllables: bez-, pronounciation: bes.xa.rak.ter.nost (bezcharakternost)
# bezkoncepčnost bes.kon.tsep.tšnost
# 	bez-kon-cep-čnost
# bezmocně be.zmo.tsňe
# 	BREAKING! word: ě, syllables: be-zmo-cn, pronounciation: e
# 	Lengths do not match. Word: bezmocně, syllables: be-zmo-cn, pronounciation: be.zmo.tsňe (bezmocně)
# bezmocnost be.zmo.tsnost
# 	be-zmo-cnost
# bezmocný be.zmo.tsnī
# 	be-zmo-cný
# bezpečí bes.pe.tšī
# 	bez-pe-čí
# bezpečně bes.pe.tšňe
# 	BREAKING! word: ě, syllables: bez-pe-čn, pronounciation: e
# 	Lengths do not match. Word: bezpečně, syllables: bez-pe-čn, pronounciation: bes.pe.tšňe (bezpečně)
# bezpečnost bes.pe.tšnost
# 	bez-pe-čnost
# bezpečnostní bes.pe.tšnos.tňī
# 	bez-pe-čnos-tní
# bezpečný bes.pe.tšnī
# 	bez-pe-čný
# bezpočet bes.po.tšet
# 	bez-po-čet
# bezpodmínečně bes.po.dmī.ne.tšňe
# 	BREAKING! word: ě, syllables: bez-po-dmí-ne-čn, pronounciation: e
# 	Lengths do not match. Word: bezpodmínečně, syllables: bez-po-dmí-ne-čn, pronounciation: bes.po.dmī.ne.tšňe (bezpodmínečně)
# bezpodmínečnost bes.po.dmī.ne.tšnost
# 	bez-po-dmí-ne-čnost
# bezpodmínečný bes.po.dmī.ne.tšnī
# 	bez-po-dmí-ne-čný
# bezpochyby bes.po.xi.bi
# 	BREAKING! word: chyby, syllables: bez-po-, pronounciation: xi.bi
# 	Lengths do not match. Word: bezpochyby, syllables: bez-po-, pronounciation: bes.po.xi.bi (bezpochyby)
# bezporuchovost bes.po.ru.xo.vost
# 	BREAKING! word: chovost, syllables: bez-po-ru-, pronounciation: xo.vost
# 	Lengths do not match. Word: bezporuchovost, syllables: bez-po-ru-, pronounciation: bes.po.ru.xo.vost (bezporuchovost)
# bezporuchový bes.po.ru.xo.vī
# 	BREAKING! word: chový, syllables: bez-po-ru-, pronounciation: xo.vī
# 	Lengths do not match. Word: bezporuchový, syllables: bez-po-ru-, pronounciation: bes.po.ru.xo.vī (bezporuchový)
# bezpracně bes.pra.tsňe
# 	BREAKING! word: ě, syllables: bez-pra-cn, pronounciation: e
# 	Lengths do not match. Word: bezpracně, syllables: bez-pra-cn, pronounciation: bes.pra.tsňe (bezpracně)
# bezpracnost bes.pra.tsnost
# 	bez-pra-cnost
# bezpracný bes.pra.tsnī
# 	bez-pra-cný
# bezprecedentní bes.pre.tse.den.tňī
# 	bez-pre-ce-den-tní
# bezpředmětně bes.pře.dmňe.tňe
# 	BREAKING! word: ětně, syllables: bez-pře-dm, pronounciation: ňe.tňe
# 	Lengths do not match. Word: bezpředmětně, syllables: bez-pře-dm, pronounciation: bes.pře.dmňe.tňe (bezpředmětně)
# bezpředmětnost bes.pře.dmňe.tnost
# 	BREAKING! word: ětnost, syllables: bez-pře-dm, pronounciation: ňe.tnost
# 	Lengths do not match. Word: bezpředmětnost, syllables: bez-pře-dm, pronounciation: bes.pře.dmňe.tnost (bezpředmětnost)
# bezpředmětný bes.pře.dmňe.tnī
# 	BREAKING! word: ětný, syllables: bez-pře-dm, pronounciation: ňe.tnī
# 	Lengths do not match. Word: bezpředmětný, syllables: bez-pře-dm, pronounciation: bes.pře.dmňe.tnī (bezpředmětný)
# bezpředmětový bes.pře.dmňe.to.vī
# 	BREAKING! word: ětový, syllables: bez-pře-dm, pronounciation: ňe.to.vī
# 	Lengths do not match. Word: bezpředmětový, syllables: bez-pře-dm, pronounciation: bes.pře.dmňe.to.vī (bezpředmětový)
# bezpříspěvkový bes.přīs.pjef.ko.vī
# 	bez-přís-pěv-ko-vý
# bezvědomí be.zvje.do.mī
# 	be-zvě-do-mí
# bezvětří be.zvje.třī
# 	be-zvě-tří
# bezvousý be.zvö.sī
# 	BREAKING! word: usý, syllables: be-zvo-, pronounciation: sī
# 	Lengths do not match. Word: bezvousý, syllables: be-zvo-, pronounciation: be.zvö.sī (bezvousý)
# bezvýchodně be.zvī.xo.dňe
# 	BREAKING! word: chodně, syllables: be-zvý-, pronounciation: xo.dňe
# 	Lengths do not match. Word: bezvýchodně, syllables: be-zvý-, pronounciation: be.zvī.xo.dňe (bezvýchodně)
# bezvýchodnost be.zvī.xo.dnost
# 	BREAKING! word: chodnost, syllables: be-zvý-, pronounciation: xo.dnost
# 	Lengths do not match. Word: bezvýchodnost, syllables: be-zvý-, pronounciation: be.zvī.xo.dnost (bezvýchodnost)
# bezvýchodný be.zvī.xo.dnī
# 	BREAKING! word: chodný, syllables: be-zvý-, pronounciation: xo.dnī
# 	Lengths do not match. Word: bezvýchodný, syllables: be-zvý-, pronounciation: be.zvī.xo.dnī (bezvýchodný)
# bezzásadově bes.zā.sa.do.vje
# 	bez-zá-sa-do-vě
# bezzubě bes.zu.bje
# 	bez-zu-bě
# běžec bje.žets
# 	bě-žec
# běžecký bje.žets.kī
# 	bě-žec-ký
# běžet bje.žet
# 	bě-žet
# běžící bje.žī.tsī
# 	bě-ží-cí
# běžka bješ.ka
# 	běž-ka
# běžkyně bješ.ki.ňe
# 	BREAKING! word: ě, syllables: běž-ky-n, pronounciation: e
# 	Lengths do not match. Word: běžkyně, syllables: běž-ky-n, pronounciation: bješ.ki.ňe (běžkyně)
# běžně bje.žňe
# 	BREAKING! word: ě, syllables: bě-žn, pronounciation: e
# 	Lengths do not match. Word: běžně, syllables: bě-žn, pronounciation: bje.žňe (běžně)
# běžnost bje.žnost
# 	bě-žnost
# běžný bje.žnī
# 	bě-žný
# béžově bē.žo.vje
# 	bé-žo-vě
# biatlon bi.ja.tlon
# 	Nothing found. BREAKING! word: atlon, syllables: bi-, pronounciation: ja.tlon
# 	Lengths do not match. Word: biatlon, syllables: bi-, pronounciation: bi.ja.tlon (biatlon)
# biblický bi.blits.kī
# 	bi-blic-ký
# biblio bi.bli.jo
# 	bi-bli-o
# bibliofil bi.bli.jo.fil
# 	bi-bli-o-fil
# bibliofilie bi.bli.jo.fī.li.je
# 	bi-bli-o-fi-li-e
# bibliofilský bi.bli.jo.fil.skī
# 	bi-bli-o-fil-ský
# bibliograf bi.bli.jo.graf
# 	bi-bli-o-graf
# bibliografický bi.bli.jo.gra.fits.kī
# 	bi-bli-o-gra-fic-ký
# bibliografie bi.bli.jo.gra.fi.je
# 	bi-bli-o-gra-fi-e
# ...
# ztéci stē.tsi
# 	zté-ci
# zteč stetš
# 	zteč
# ztechnizovaný ste.xni.zo.va.nī
# 	BREAKING! word: chnizovaný, syllables: zte-, pronounciation: xni.zo.va.nī
# 	Lengths do not match. Word: ztechnizovaný, syllables: zte-, pronounciation: ste.xni.zo.va.nī (ztechnizovaný)
# ztechnizovat ste.xni.zo.vat
# 	BREAKING! word: chnizovat, syllables: zte-, pronounciation: xni.zo.vat
# 	Lengths do not match. Word: ztechnizovat, syllables: zte-, pronounciation: ste.xni.zo.vat (ztechnizovat)
# ztenčit sten.tšit
# 	zten-čit
# ztenčovat sten.tšo.vat
# 	zten-čo-vat
# ztěžknout sťeš.knöt
# 	Nothing found. BREAKING! word: těžknout, syllables: z, pronounciation: ťeš.knöt
# 	Lengths do not match. Word: ztěžknout, syllables: z, pronounciation: sťeš.knöt (ztěžknout)
# zticha sťi.xa
# 	BREAKING! word: cha, syllables: zti-, pronounciation: xa
# 	Lengths do not match. Word: zticha, syllables: zti-, pronounciation: sťi.xa (zticha)
# ztichlý sťi.xlī
# 	BREAKING! word: chlý, syllables: zti-, pronounciation: xlī
# 	Lengths do not match. Word: ztichlý, syllables: zti-, pronounciation: sťi.xlī (ztichlý)
# ztichnout sťi.xnöt
# 	BREAKING! word: chnout, syllables: zti-, pronounciation: xnöt
# 	Lengths do not match. Word: ztichnout, syllables: zti-, pronounciation: sťi.xnöt (ztichnout)
# ztloustlý stlös.tlī
# 	BREAKING! word: oustlý, syllables: ztl, pronounciation: ös.tlī
# 	Lengths do not match. Word: ztloustlý, syllables: ztl, pronounciation: stlös.tlī (ztloustlý)
# ztloustnout stlös.tnöt
# 	BREAKING! word: oustnout, syllables: ztl, pronounciation: ös.tnöt
# 	Lengths do not match. Word: ztloustnout, syllables: ztl, pronounciation: stlös.tnöt (ztloustnout)
# ztmavět stma.vjet
# 	ztma-vět
# ztmavnout stma.vnöt
# 	BREAKING! word: out, syllables: ztma-vn, pronounciation: öt
# 	Lengths do not match. Word: ztmavnout, syllables: ztma-vn, pronounciation: stma.vnöt (ztmavnout)
# ztraceno stra.tse.no
# 	ztra-ce-no
# ztracený stra.tse.nī
# 	ztra-ce-ný
# ztrácet strā.tset
# 	ztrá-cet
# ztrmácený str.mā.tse.nī
# 	ztr-má-ce-ný
# ztroskotanec stros.ko.ta.nets
# 	ztros-ko-ta-nec
# ztrouchnivělý strö.xňi.vje.lī
# 	BREAKING! word: uchnivělý, syllables: ztro-, pronounciation: xňi.vje.lī
# 	Lengths do not match. Word: ztrouchnivělý, syllables: ztro-, pronounciation: strö.xňi.vje.lī (ztrouchnivělý)
# ztrouchnivět strö.xňi.vjet
# 	BREAKING! word: uchnivět, syllables: ztro-, pronounciation: xňi.vjet
# 	Lengths do not match. Word: ztrouchnivět, syllables: ztro-, pronounciation: strö.xňi.vjet (ztrouchnivět)
# ztrpčit strp.tšit
# 	ztrp-čit
# ztrpčovat strp.tšo.vat
# 	ztrp-čo-vat
# ztrpknout strp.knöt
# 	BREAKING! word: out, syllables: ztrp-kn, pronounciation: öt
# 	Lengths do not match. Word: ztrpknout, syllables: ztrp-kn, pronounciation: strp.knöt (ztrpknout)
# ztřeštěnec střeš.ťe.nets
# 	Nothing found. BREAKING! word: těnec, syllables: ztřeš-, pronounciation: ťe.nets
# 	Lengths do not match. Word: ztřeštěnec, syllables: ztřeš-, pronounciation: střeš.ťe.nets (ztřeštěnec)
# ztuhnout stu.hnöt
# 	BREAKING! word: out, syllables: ztu-hn, pronounciation: öt
# 	Lengths do not match. Word: ztuhnout, syllables: ztu-hn, pronounciation: stu.hnöt (ztuhnout)
# ztuchlina stu.xli.na
# 	BREAKING! word: chlina, syllables: ztu-, pronounciation: xli.na
# 	Lengths do not match. Word: ztuchlina, syllables: ztu-, pronounciation: stu.xli.na (ztuchlina)
# ztuchlý stu.xlī
# 	BREAKING! word: chlý, syllables: ztu-, pronounciation: xlī
# 	Lengths do not match. Word: ztuchlý, syllables: ztu-, pronounciation: stu.xlī (ztuchlý)
# ztuchnout stu.xnöt
# 	BREAKING! word: chnout, syllables: ztu-, pronounciation: xnöt
# 	Lengths do not match. Word: ztuchnout, syllables: ztu-, pronounciation: stu.xnöt (ztuchnout)
# ztvrdnout stvr.dnöt
# 	BREAKING! word: out, syllables: ztvr-dn, pronounciation: öt
# 	Lengths do not match. Word: ztvrdnout, syllables: ztvr-dn, pronounciation: stvr.dnöt (ztvrdnout)
# zurčet zur.tšet
# 	zur-čet
# zuřivě zu.ři.vje
# 	zu-ři-vě
# zuřivec zu.ři.vets
# 	zu-ři-vec
# zušlechtit zu.šlex.ťit
# 	Nothing found. BREAKING! word: htit, syllables: zu-šlec-, pronounciation: ťit
# 	Lengths do not match. Word: zušlechtit, syllables: zu-šlec-, pronounciation: zu.šlex.ťit (zušlechtit)
# zušlechťovat zu.šlex.ťo.vat
# 	Nothing found. BREAKING! word: hťovat, syllables: zu-šlec-, pronounciation: ťo.vat
# 	Lengths do not match. Word: zušlechťovat, syllables: zu-šlec-, pronounciation: zu.šlex.ťo.vat (zušlechťovat)
# zvadnout zva.dnöt
# 	BREAKING! word: out, syllables: zva-dn, pronounciation: öt
# 	Lengths do not match. Word: zvadnout, syllables: zva-dn, pronounciation: zva.dnöt (zvadnout)
# zválcovat zvāl.tso.vat
# 	zvál-co-vat
# zvečera zve.tše.ra
# 	zve-če-ra
# zvěčnit zvje.tšňit
# 	zvě-čnit
# zvěd zvjet
# 	Nothing found. BREAKING! word: d, syllables: zvě, pronounciation: t
# 	Lengths do not match. Word: zvěd, syllables: zvě, pronounciation: zvjet (zvěd)
# zvedací zve.da.tsī
# 	zve-da-cí
# zvědavě zvje.da.vje
# 	zvě-da-vě
# zvědavec zvje.da.vets
# 	zvě-da-vec
# zvědavost zvje.da.vost
# 	zvě-da-vost
# zvědavý zvje.da.vī
# 	zvě-da-vý
# zvědečtit zvje.detš.ťit
# 	zvě-deč-tit
# zvědečťovat zvje.detš.ťo.vat
# 	zvě-deč-ťo-vat
# zvědět zvje.ďet
# 	Nothing found. BREAKING! word: dět, syllables: zvě-, pronounciation: ďet
# 	Lengths do not match. Word: zvědět, syllables: zvě-, pronounciation: zvje.ďet (zvědět)
# zvednout zve.dnöt
# 	BREAKING! word: out, syllables: zve-dn, pronounciation: öt
# 	Lengths do not match. Word: zvednout, syllables: zve-dn, pronounciation: zve.dnöt (zvednout)
# zvědy zvje.di
# 	zvě-dy
# zvelebovací zve.le.bo.va.tsī
# 	zve-le-bo-va-cí
# zveličit zve.li.tšit
# 	zve-li-čit
# zveličovat zve.li.tšo.vat
# 	zve-li-čo-vat
# zvenčí zven.tšī
# 	zven-čí
# zvěrokruh zvje.ro.krux
# 	Nothing found. BREAKING! word: h, syllables: zvě-ro-kru, pronounciation: x
# 	Lengths do not match. Word: zvěrokruh, syllables: zvě-ro-kru, pronounciation: zvje.ro.krux (zvěrokruh)
# zvěrolékař zvje.ro.lē.kař
# 	zvě-ro-lé-kař
# zvěrolékařský zvje.ro.lē.kař.skī
# 	zvě-ro-lé-kař-ský
# zvěrolékařství zvje.ro.lē.kař.stvī
# 	zvě-ro-lé-kař-ství
# zvěrstvo zvjers.tvo
# 	zvěrs-tvo
# zvěř zvjeř
# 	zvěř
# zvěřina zvje.ři.na
# 	zvě-ři-na
# zvěřinec zvje.ři.nets
# 	zvě-ři-nec
# zvěst zvjest
# 	zvěst
# zvěstovat zvjes.to.vat
# 	zvěs-to-vat
# zvětralý zvje.tra.lī
# 	zvě-tra-lý
# zvětrat zvje.trat
# 	zvě-trat
# zvětrávat zvje.trā.vat
# 	zvě-trá-vat
# zvětřit zvje.třit
# 	zvě-třit
# zvětšenina zvje.tše.ňi.na
# 	zvě-tše-ni-na
# zvětšený zvje.tše.nī
# 	zvě-tše-ný
# zvětšit zvje.tšit
# 	zvě-tšit
# zvětšovací zvje.tšo.va.tsī
# 	zvě-tšo-va-cí
# zvětšovat zvje.tšo.vat
# 	zvě-tšo-vat
# zvídavě zvī.da.vje
# 	zví-da-vě
# zvířecí zvī.ře.tsī
# 	zví-ře-cí
# zvířeckost zvī.řets.kost
# 	zví-řec-kost
# zvířecky zvī.řets.ki
# 	zví-řec-ky
# zvířecký zvī.řets.kī
# 	zví-řec-ký
# zvířectvo zvī.řets.tvo
# 	zví-řec-tvo
# zvláčnět zvlā.tšňet
# 	zvlá-čnět
# zvláčnit zvlā.tšňit
# 	zvlá-čnit
# zvláčňovat zvlā.tšňo.vat
# 	zvlá-čňo-vat
# zvládnout zvlā.dnöt
# 	BREAKING! word: out, syllables: zvlá-dn, pronounciation: öt
# 	Lengths do not match. Word: zvládnout, syllables: zvlá-dn, pronounciation: zvlā.dnöt (zvládnout)
# zvlčile zvl.tši.le
# 	zvl-či-le
# zvlčilost zvl.tši.lost
# 	zvl-či-lost
# zvlčilý zvl.tši.lī
# 	zvl-či-lý
# zvlhčit zvlx.tšit
# 	zvlh-čit
# zvlhčovat zvlx.tšo.vat
# 	zvlh-čo-vat
# zvlhnout zvl.hnöt
# 	BREAKING! word: out, syllables: zvl-hn, pronounciation: öt
# 	Lengths do not match. Word: zvlhnout, syllables: zvl-hn, pronounciation: zvl.hnöt (zvlhnout)
# zvolací zvo.la.tsī
# 	zvo-la-cí
# zvonec zvo.nets
# 	zvo-nec
# zvoneček zvo.ne.tšek
# 	zvo-ne-ček
# zvonice zvo.ňi.tse
# 	zvo-ni-ce
# zvonivě zvo.ňi.vje
# 	zvo-ni-vě
# zvráceně zvrā.tse.ňe
# 	BREAKING! word: ě, syllables: zvrá-ce-n, pronounciation: e
# 	Lengths do not match. Word: zvráceně, syllables: zvrá-ce-n, pronounciation: zvrā.tse.ňe (zvráceně)
# zvrácenost zvrā.tse.nost
# 	zvrá-ce-nost
# zvrácený zvrā.tse.nī
# 	zvrá-ce-ný
# zvracet zvra.tset
# 	zvra-cet
# zvrhnout zvr.hnöt
# 	BREAKING! word: out, syllables: zvr-hn, pronounciation: öt
# 	Lengths do not match. Word: zvrhnout, syllables: zvr-hn, pronounciation: zvr.hnöt (zvrhnout)
# zvrtnout zvr.tnöt
# 	BREAKING! word: out, syllables: zvr-tn, pronounciation: öt
# 	Lengths do not match. Word: zvrtnout, syllables: zvr-tn, pronounciation: zvr.tnöt (zvrtnout)
# zvučet zvu.tšet
# 	zvu-čet
# zvučně zvu.tšňe
# 	BREAKING! word: ě, syllables: zvu-čn, pronounciation: e
# 	Lengths do not match. Word: zvučně, syllables: zvu-čn, pronounciation: zvu.tšňe (zvučně)
# zvučnost zvu.tšnost
# 	zvu-čnost
# zvučný zvu.tšnī
# 	zvu-čný
# zvukově zvu.ko.vje
# 	zvu-ko-vě
# zvýhodňující zvī.ho.dňu.jī.tsī
# 	zvý-ho-dňu-jí-cí
# zvyknout zvi.knöt
# 	BREAKING! word: out, syllables: zvy-kn, pronounciation: öt
# 	Lengths do not match. Word: zvyknout, syllables: zvy-kn, pronounciation: zvi.knöt (zvyknout)
# žabička ža.bitš.ka
# 	ža-bič-ka
# žabinec ža.bi.nets
# 	ža-bi-nec
# žací ža.tsī
# 	ža-cí
# žactvo žats.tvo
# 	žac-tvo
# žáček žā.tšek
# 	žá-ček
# žačka žatš.ka
# 	žač-ka
# žádací žā.da.tsī
# 	žá-da-cí
# žádostivě žā.dos.ťi.vje
# 	žá-dos-ti-vě
# žalobce ža.lop.tse
# 	ža-lob-ce
# žalobnice ža.lob.ňi.tse
# 	ža-lob-ni-ce
# žalobníček ža.lob.ňī.tšek
# 	ža-lob-ní-ček
# žalozpěv ža.los.pjef
# 	Nothing found. BREAKING! word: v, syllables: ža-loz-pě, pronounciation: f
# 	Lengths do not match. Word: žalozpěv, syllables: ža-loz-pě, pronounciation: ža.los.pjef (žalozpěv)
# žaludeční ža.lu.de.tšňī
# 	ža-lu-de-ční
# žaluzie ža.lu.zi.je
# 	ža-lu-zi-e
# žampion žam.pi.jon
# 	žam-pi-on
# žampionový žam.pi.jo.no.vī
# 	žam-pi-o-no-vý
# žánrově žān.ro.vje
# 	žán-ro-vě
# žárlivě žār.li.vje
# 	žár-li-vě
# žárlivec žār.li.vets
# 	žár-li-vec
# žasnout ža.snöt
# 	BREAKING! word: out, syllables: ža-sn, pronounciation: öt
# 	Lengths do not match. Word: žasnout, syllables: ža-sn, pronounciation: ža.snöt (žasnout)
# žblunknout šblun.knöt
# 	BREAKING! word: out, syllables: žblun-kn, pronounciation: öt
# 	Lengths do not match. Word: žblunknout, syllables: žblun-kn, pronounciation: šblun.knöt (žblunknout)
# ždibec šďi.bets
# 	Nothing found. BREAKING! word: ždibec, syllables: , pronounciation: šďi.bets
# 	Lengths do not match. Word: ždibec, syllables: , pronounciation: šďi.bets (ždibec)
# ždibeček šďi.be.tšek
# 	Nothing found. BREAKING! word: ždibeček, syllables: , pronounciation: šďi.be.tšek
# 	Lengths do not match. Word: ždibeček, syllables: , pronounciation: šďi.be.tšek (ždibeček)
# ždímačka šďī.matš.ka
# 	Nothing found. BREAKING! word: ždímačka, syllables: , pronounciation: šďī.matš.ka
# 	Lengths do not match. Word: ždímačka, syllables: , pronounciation: šďī.matš.ka (ždímačka)
# žebrácký že.brāts.kī
# 	že-brác-ký
# žebračenka že.bra.tšen.ka
# 	že-bra-čen-ka
# žebračka že.bratš.ka
# 	že-brač-ka
# žebravě že.bra.vje
# 	že-bra-vě
# žebříček že.břī.tšek
# 	že-bří-ček
# žehlicí že.hli.tsī
# 	že-hli-cí
# žehlička že.hlitš.ka
# 	že-hlič-ka
# železnice že.le.zňi.tse
# 	že-le-zni-ce
# železničář že.le.zňi.tšāř
# 	že-le-zni-čář
# železničářka že.le.zňi.tšāř.ka
# 	že-le-zni-čář-ka
# železničářský že.le.zňi.tšāř.skī
# 	že-le-zni-čář-ský
# železniční že.le.zňi.tšňī
# 	že-le-zni-ční
# želvička žel.vitš.ka
# 	žel-vič-ka
# žemlička žem.litš.ka
# 	žem-lič-ka
# ženáč že.nātš
# 	že-náč
# ženich že.ňix
# 	BREAKING! word: ch, syllables: že-ni, pronounciation: x
# 	Lengths do not match. Word: ženich, syllables: že-ni, pronounciation: že.ňix (ženich)
# žentour žen.tör
# 	BREAKING! word: our, syllables: žen-t, pronounciation: ör
# 	Lengths do not match. Word: žentour, syllables: žen-t, pronounciation: žen.tör (žentour)
# žhavě šha.vje
# 	žha-vě
# žhavicí šha.vi.tsī
# 	žha-vi-cí
# žhnout šhnöt
# 	BREAKING! word: out, syllables: žhn, pronounciation: öt
# 	Lengths do not match. Word: žhnout, syllables: žhn, pronounciation: šhnöt (žhnout)
# židlička ži.dlitš.ka
# 	ži-dlič-ka
# žinčice žin.tši.tse
# 	žin-či-ce
# živáček ži.vā.tšek
# 	ži-vá-ček
# živě ži.vje
# 	ži-vě
# živec ži.vets
# 	ži-vec
# živice ži.vi.tse
# 	ži-vi-ce
# živičný ži.vi.tšnī
# 	ži-vi-čný
# živio ži.vi.jo
# 	ži-vi-o
# živnostnice ži.vnos.tňi.tse
# 	ži-vnos-tni-ce
# živnostnický ži.vnos.tňits.kī
# 	ži-vnos-tnic-ký
# živočišně ži.vo.tši.šňe
# 	BREAKING! word: ě, syllables: ži-vo-či-šn, pronounciation: e
# 	Lengths do not match. Word: živočišně, syllables: ži-vo-či-šn, pronounciation: ži.vo.tši.šňe (živočišně)
# živočišnost ži.vo.tši.šnost
# 	ži-vo-či-šnost
# živočišný ži.vo.tši.šnī
# 	ži-vo-či-šný
# živočišstvo ži.vo.tšiš.stvo
# 	ži-vo-čiš-stvo
# životaschopnost ži.vo.tas.xo.pnost
# 	BREAKING! word: chopnost, syllables: ži-vo-tas-, pronounciation: xo.pnost
# 	Lengths do not match. Word: životaschopnost, syllables: ži-vo-tas-, pronounciation: ži.vo.tas.xo.pnost (životaschopnost)
# životaschopný ži.vo.tas.xo.pnī
# 	BREAKING! word: chopný, syllables: ži-vo-tas-, pronounciation: xo.pnī
# 	Lengths do not match. Word: životaschopný, syllables: ži-vo-tas-, pronounciation: ži.vo.tas.xo.pnī (životaschopný)
# životopisec ži.vo.to.pi.sets
# 	ži-vo-to-pi-sec
# žíznivě žī.zňi.vje
# 	ží-zni-vě
# žloutek žlö.tek
# 	BREAKING! word: utek, syllables: žlo-, pronounciation: tek
# 	Lengths do not match. Word: žloutek, syllables: žlo-, pronounciation: žlö.tek (žloutek)
# žloutenka žlö.ten.ka
# 	BREAKING! word: utenka, syllables: žlo-, pronounciation: ten.ka
# 	Lengths do not match. Word: žloutenka, syllables: žlo-, pronounciation: žlö.ten.ka (žloutenka)
# žloutenkový žlö.ten.ko.vī
# 	BREAKING! word: utenkový, syllables: žlo-, pronounciation: ten.ko.vī
# 	Lengths do not match. Word: žloutenkový, syllables: žlo-, pronounciation: žlö.ten.ko.vī (žloutenkový)
# žloutkový žlöt.ko.vī
# 	BREAKING! word: outkový, syllables: žl, pronounciation: öt.ko.vī
# 	Lengths do not match. Word: žloutkový, syllables: žl, pronounciation: žlöt.ko.vī (žloutkový)
# žloutnoucí žlö.tnö.tsī
# 	BREAKING! word: utnoucí, syllables: žlo-, pronounciation: tnö.tsī
# 	Lengths do not match. Word: žloutnoucí, syllables: žlo-, pronounciation: žlö.tnö.tsī (žloutnoucí)
# žloutnout žlö.tnöt
# 	BREAKING! word: utnout, syllables: žlo-, pronounciation: tnöt
# 	Lengths do not match. Word: žloutnout, syllables: žlo-, pronounciation: žlö.tnöt (žloutnout)
# žluč žlutš
# 	žluč
# žlučník žlu.tšňīk
# 	žlu-čník
# žlučníkový žlu.tšňī.ko.vī
# 	žlu-ční-ko-vý
# žlučovitý žlu.tšo.vi.tī
# 	žlu-čo-vi-tý
# žlučovod žlu.tšo.vot
# 	Nothing found. BREAKING! word: d, syllables: žlu-čo-vo, pronounciation: t
# 	Lengths do not match. Word: žlučovod, syllables: žlu-čo-vo, pronounciation: žlu.tšo.vot (žlučovod)
# žlučový žlu.tšo.vī
# 	žlu-čo-vý
# žluknout žlu.knöt
# 	BREAKING! word: out, syllables: žlu-kn, pronounciation: öt
# 	Lengths do not match. Word: žluknout, syllables: žlu-kn, pronounciation: žlu.knöt (žluknout)
# žluťácký žlu.ťāts.kī
# 	žlu-ťác-ký
# žlutavě žlu.ta.vje
# 	žlu-ta-vě
# žlutočerveně žlu.to.tšer.ve.ňe
# 	BREAKING! word: ě, syllables: žlu-to-čer-ve-n, pronounciation: e
# 	Lengths do not match. Word: žlutočerveně, syllables: žlu-to-čer-ve-n, pronounciation: žlu.to.tšer.ve.ňe (žlutočerveně)
# žlutočervený žlu.to.tšer.ve.nī
# 	žlu-to-čer-ve-ný
# žluťounký žlu.ťön.kī
# 	BREAKING! word: ounký, syllables: žlu-ť, pronounciation: ön.kī
# 	Lengths do not match. Word: žluťounký, syllables: žlu-ť, pronounciation: žlu.ťön.kī (žluťounký)
# žmoulat žmö.lat
# 	BREAKING! word: ulat, syllables: žmo-, pronounciation: lat
# 	Lengths do not match. Word: žmoulat, syllables: žmo-, pronounciation: žmö.lat (žmoulat)
# žnec žnets
# 	žnec
# žnečka žnetš.ka
# 	žneč-ka
# žnout žnöt
# 	BREAKING! word: out, syllables: žn, pronounciation: öt
# 	Lengths do not match. Word: žnout, syllables: žn, pronounciation: žnöt (žnout)
# žoldácký žol.dāts.kī
# 	žol-dác-ký
# žoviálně žo.vi.jāl.ňe
# 	BREAKING! word: ě, syllables: žo-vi-ál-n, pronounciation: e
# 	Lengths do not match. Word: žoviálně, syllables: žo-vi-ál-n, pronounciation: žo.vi.jāl.ňe (žoviálně)
# žoviální žo.vi.jāl.ňī
# 	žo-vi-ál-ní
# žoviálnost žo.vi.jāl.nost
# 	žo-vi-ál-nost
# žraločí žra.lo.tšī
# 	žra-lo-čí
# žravě žra.vje
# 	žra-vě
# žrec žrets
# 	žrec
# žuchnout žu.xnöt
# 	BREAKING! word: chnout, syllables: žu-, pronounciation: xnöt
# 	Lengths do not match. Word: žuchnout, syllables: žu-, pronounciation: žu.xnöt (žuchnout)
# žurnalisticky žur.na.lis.tits.ki
# 	žur-na-lis-tic-ky
# žurnalistický žur.na.lis.tits.kī
# 	žur-na-lis-tic-ký
# žvanec žva.nets
# 	žva-nec
# žvatlavě žva.tla.vje
# 	žva-tla-vě
# žvýkací žvī.ka.tsī
# 	žvý-ka-cí
# žvýkačka žvī.katš.ka
# 	žvý-kač-ka
#            Word Pronounciation Syllables
# 2          abbé           a.bē
# 172    achilles       a.xi.les
# 170       achát          a.xāt
# 171    achátový     a.xā.to.vī
# 119    aerotaxi  a.e.ro.tak.si
# ...         ...            ...       ...
# 49191     žínka         žīn.ka    žín-ka
# 49192       žír            žīr       žír
# 49197     žírný         žīr.nī    žír-ný
# 49198       žít            žīt       žít
# 49305     žňový         žňo.vī    žňo-vý
#
# [45097 rows x 3 columns]

# %%
annotated_len = df[df['Syllables'] != ''].shape[0]
len_all = df.shape[0]
print(f'Annotated {annotated_len} ouf of {len_all} words ({annotated_len / len_all * 100:.2f} %)')
# Out:
# Annotated 39339 ouf of 45097 words (87.23 %)

# %% [markdown]
# Save annonated words to `txt` file.

# %%
annotated = df[df['Syllables'] != '']
annotated['Syllables'].to_csv(os.path.join('..', 'dataset', 'annotated.txt'), index=False)

# %% [markdown]
# Get stats about length of words WITHOUT syllables signes.

# %%
df.describe()
# Out:
#            Word_len
# count  45097.000000
# mean       8.080959
# std        2.380436
# min        1.000000
# 25%        6.000000
# 50%        8.000000
# 75%       10.000000
# max       23.000000

# %% [markdown]
# ### Example of how to normalize special czech characters

# %%
import unicodedata
my_unicode = 'ē'
output = unicodedata.normalize('NFD', my_unicode).encode('ascii', 'ignore').decode()
output
# Out:
# 'e'

# %% [markdown]
# ## Simple example of webScrapping with python's BeautifulSoup library
# original code available at [https://github.com/DIFS-Teaching/webscraping](https://github.com/DIFS-Teaching/webscraping/blob/main/python-beautiful-soup/bsoup.py)

# %%
from bs4 import BeautifulSoup
import requests

html = requests.get("https://www.fit.vut.cz/study/courses/").text
soup = BeautifulSoup(html, "html.parser")
rows = soup.select("#list")[0].find_all("tr")

# Get headers
for cell in rows[0].find_all('th'):
    print(cell.text, end=";")
print()

# Get data
for row in rows[1:]:
    cells = row.find_all('td')
    out = "";
    for cell in cells:
        out = out + cell.text + ";"
    print(out)
# Out:
# Title;Abbrv;Sem;Cred;Compl;Dept;
# Mathematical Software;0MS;S;3;Cr;ÚM;
# Calculus with MAPLE;0MV;S;2;Cr;ÚM;
# Computer Physics I;T1F;S;3;ClCr;ÚFI;
# Computer Physics II;T2F;W;3;ClCr;ÚFI;
# General Algebra;SOA;S;5;Cr+Ex;ÚM;
# History of Design 2 - winter;DEDE2-Z;W;3;Ex;KTDU;
# Architecture of the 20th century;ACHE20;W;3;Ex;KTDU;
# History of Design 1 - winter;DEDE1-Z;W;3;Ex;KTDU;
# Copyright;AUP-L;S;1;Cr;KTDU;
# History of Design 1 - summer;DEDE1-L;S;3;Ex;KTDU;
# History of Design 2 - summer;DEDE2-L;S;3;Ex;KTDU;
# Linear Algebra I;SLA;W;6;Cr+Ex;ÚM;
# German 1;N1;W;2;Cr;ÚJ;
# German 2;N2;S;3;Cr+Ex;ÚJ;
# German 3;N3;W;2;Cr;ÚJ;
# German 4;N4;S;3;Cr+Ex;ÚJ;
# Russian 1;R1;W;2;Cr;ÚJ;
# Russian 2;R2;S;3;Cr+Ex;ÚJ;
# French 1;F1;W;2;Cr;ÚJ;
# French 2;F2;S;3;Cr+Ex;ÚJ;
# History and Philosophy of Technology;FIT;S;2;ClCr;ICV;
# History and Philosophy of Technology;FIT;W;2;ClCr;ICV;
# Fundamentals of Law;PRM;S;2;ClCr;ICV;
# Fundamentals of Law;PRM;W;2;ClCr;ICV;
# Rhetoric;RET;S;2;ClCr;ICV;
# Rhetoric;RET;W;2;ClCr;ICV;
# Porn studies;KPO-Z;W;3;Ex;ATD;
# Philosophy and the Culture;FIK;S;2;Cr;ICV;
# Philosophy and the Culture;FIK;W;2;Cr;ICV;
# 3D Optical digitalization 1;1ODI-Z;W;2;Cr;K3D;
# 3D Optical digitalization 2;1ODI-L;S;2;Cr;K3D;
# Financial Management for Informatics;IfmiP;W;3;ClCr;ÚF;
# German 5;N5;W;2;Cr;ÚJ;
# Macroeconomics 1;mak1P;W;6;Cr+Ex;ÚE;
# Microeconomics 1;mik1P;S;6;Cr+Ex;ÚE;
# Accounting;uceP;S;6;Cr+Ex;ÚF;
# Financial Analysis and Planning;fapP;S;5;Cr+Ex;ÚF;
# 3D Printing and Digital Fabrication for Creative Industries 1;1DS-Z;W;2;Cr;K3D;
# Czech Art Between 1900–1945 in Contexts;1CU20st-Z;W;3;Ex;KTDU;
# Czech Art Between 1945–1990 in Contexts;1CU20st-L;S;3;Ex;KTDU;
# German 6;N6;S;4;Cr+Ex;ÚJ;
# Tax System;KdasP;S;6;Cr+Ex;ÚF;
# Mobile Robots;0MR;S;5;Cr;ÚAI;
# The History and Context of Photography 1;DKFI-Z;W;3;Ex;KTDU;
# The History and Context of Photography 2;DKFII-L;S;3;Ex;KTDU;
# English B2-1;0A7;W;2;Cr;ÚJ;
# English B2-2;0A8;S;3;Cr+Ex;ÚJ;
# English Skills for Workplace Communication;0SE;S;3;Cr+Ex;ÚJ;
# English Skills for Workplace Communication;0SE;W;3;Cr+Ex;ÚJ;
# English C1-1;0A9;W;3;Cr+Ex;ÚJ;
# English C1-2;0AX;S;3;Cr+Ex;ÚJ;
# Spanish for Beginners 1/2;JS1;W;3;Cr;UJAZ;
# Molecular Genetics I;BC_MOG1;W;4;Ex;ÚCHPBT;
# Analog Technology;BPC-ANA;W;6;Cr+Ex;UTKO;
# Analog Electronics 1;BPC-AE1;W;7;Cr+Ex;UREL;
# Control Theory 2;BPC-RR2;S;6;Cr+Ex;UAMT;
# Communication Systems for IoT;BPC-IOT;S;5;Cr+Ex;UTKO;
# Selected parts from mathematics II.;XPC-VPM;S;5;Ex;UMAT;
# Electroacoustics 1;BPC-ELA;W;6;Cr+Ex;UTKO;
# Audio Electronics;BPC-AUD;S;5;Cr+Ex;UREL;
# Design and Fabrication of Electronic Instruments;BPC-NRP;W;6;Cr+Ex;UMEL;
# Computer aided Design;BPC-PPK;S;6;ClCr;UVEE;
# Printed Circuits and Surface Mount Technology;BPC-PSM;S;5;Cr+Ex;UETE;
# Control Theory 1;BPC-RR1;W;7;Cr+Ex;UAMT;
# Tax System of the Czech Republic;BPC-DSY;W;2;ClCr;UJAZ;
# Selected parts from mathematics I.;BPC-VPA;W;5;Ex;UMAT;
# Security Systems;BPC-ZSY;W;5;Cr+Ex;UTKO;
# Robotics and Computer Vision;BPC-PRP;S;7;Cr+Ex;UAMT;
# Fundamentals of Musical Acoustics;BPC-ZHA;W;3;Ex;HF JAMU;
# Chemoinformatics;MPA-CHM;S;5;Cr+Ex;UBMI;
# Physics 1;BPC-FY1B;W;6;Cr+Ex;UFYZ;
# Audio Software;BPC-ZSW;S;2;Cr;HF JAMU;
# Analog Electronics 2;BPC-AE2;S;6;Cr+Ex;UREL;
# Robotics and Robotic Manipulators;BPC-RBM;W;4;Cr+Ex;UAMT;
# Design of Data Networks;BPC-PDS;W;5;Cr+Ex;UETE;
# Digital Audio Signal Processing;MPC-CAS;W;6;Cr+Ex;UTKO;
# Matrices and Tensors Calculus;MPC-MAT;S;5;Cr+Ex;UMAT;
# English for Europe;AEU;S;3;Cr+Ex;UJAZ;
# English for Europe;AEU;W;3;Cr+Ex;UJAZ;
# Agents and Multiagent Systems;AGS;W;5;Ex;UITS;
# Audio and Speech Processing by Humans and Machines;ASD;W;0;Ex;UPGM;
# Information Systems Analysis and Design;AIS;W;5;Cr+Ex;UIFS;
# English for IT;AIT;W;3;Cr+Ex;UJAZ;
# English for IT;AIT;S;3;Cr+Ex;UJAZ;
# Selected Topics on Language Parsing and Translation;APD;W;0;Ex;UIFS;
# Headway Pre-Intermediate 2;BAN2;S;3;Cr+Ex;UJAZ;
# Headway Pre-Intermediate 2;BAN2;W;3;Cr+Ex;UJAZ;
# New Headway Intermediate 1;BAN3;S;3;Cr+Ex;UJAZ;
# New Headway Intermediate 1;BAN3;W;3;Cr+Ex;UJAZ;
# English for Bachelors - Intermediate 2;BAN4;S;3;Cr+Ex;UJAZ;
# English for Bachelors - Intermediate 2;BAN4;W;3;Cr+Ex;UJAZ;
# Information System Security and Cryptography;BID;S;0;Ex;UITS;
# Bioinformatics;BIF;S;5;Ex;UPSY;
# Bio-Inspired Computers;BIN;S;5;Ex;UPSY;
# Biometric Systems;BIO;W;5;Cr+Ex;UITS;
# Information System Security;BIS;W;5;Cr+Ex;UITS;
# Wireless and Mobile Networks;BMS;W;5;Cr+Ex;UITS;
# Design and Security of Enterprise Networks;CCS;W;5;ClCr;UIFS;
# Network Cabling and Routing (CCNA1+CCNA2);I1C;W;4;ClCr;UIFS;
# Master's Thesis (in English);DIPe;S;13;ClCr;UPSY;
# Master's Thesis;DIP;S;13;Cr;UPSY;
# Dynamic Languages;DJA;S;5;Ex;UITS;
# Economics of Information Products;EIP;W;5;Ex;UIFS;
# Evolutionary and neural hardware;EUD;S;0;Ex;UPSY;
# Evolutionary Computation;EVD;S;0;Ex;UPSY;
# Applied Evolutionary Algorithms;EVO;S;5;Ex;UPSY;
# Formal Program Analysis;FAD;W;0;Ex;UITS;
# English: Practical Course of Business Conversation and Presentation;FCE;W;3;Cr;UPSY;
# Functional and Logic Programming;FLP;S;5;Cr+Ex;UIFS;
# Functional Verification of Digital Systems;FVS;S;5;Ex;UPSY;
# Physical Optics;FYO;S;5;Ex;UFYZ;
# Graph Algorithms;GAL;W;5;Ex;UIFS;
# Geographical Information Systems;GIS;S;5;Cr+Ex;UITS;
# Graphical User Interfaces in Java;GJA;W;5;Cr+Ex;UPGM;
# Graphic and Multimedia Processors;GMU;W;5;Cr+Ex;UPSY;
# Graphical User Interfaces in X Window System;GUX;W;5;Ex;UIFS;
# Graphical and Sound Interfaces and Standards;GZN;W;5;Ex;UPGM;
# Communication and Presentation Skills;HKO;W;3;Cr;UPSY;
# Communication and Presentation Skills;HKO;S;3;Cr;UPSY;
# Hardware/Software Codesign;HSC;W;5;Cr+Ex;UPSY;
# Leadership and Time Management;HVR;W;3;Cr;UPSY;
# Leadership and Time Management;HVR;S;3;Cr;UPSY;
# Algorithms (in English);IALe;S;5;Cr+Ex;UIFS;
# Algorithms;IAL;W;5;Cr+Ex;UIFS;
# Advanced Mathematics;IAM;S;5;ClCr;UITS;
# Binary Code Analysis;IAN;S;4;ClCr;UITS;
# Machine Level Programming;ISU;S;6;Cr+Ex;UITS;
# Security and Computer Networks;IBS;S;4;Cr+Ex;UIFS;
# Bachelor's Thesis (in English);IBTe;S;13;ClCr;UIFS;
# Bachelor's Thesis;IBT;S;13;Cr;UPSY;
# The C++ Programming Language;ICP;S;4;Cr;UITS;
# Database Systems;IDS;S;5;Cr+Ex;UIFS;
# Database Systems (in English);IDSe;S;5;Cr+Ex;UIFS;
# Electronics for Information Technology;IEL;W;6;Cr+Ex;UITS;
# Electronics for Information Technology (in English);IELe;W;6;Ex;UITS;
# Formal Languages and Compilers;IFJ;W;5;Cr+Ex;UIFS;
# Formal Languages and Compilers (in English);IFJe;W;5;Cr+Ex;UIFS;
# Seminar of Physics;IFS;W;2;Cr;UFYZ;
# Mechanics and Acoustics;IMK;S;6;ClCr;UFYZ;
# Information Systems;IIS;W;4;Cr+Ex;UIFS;
# IBM zSeries Servers;IIZ;S;5;ClCr;UITS;
# Java Programming Language;IJA;S;4;Cr;UITS;
# The C Programming Language;IJC;S;5;Ex;UITS;
# Advanced Topics of Linux Administration;ILI;W;4;ClCr;UITS;
# Mathematical Foundations of Fuzzy Logic;IMF;W;5;ClCr;UMAT;
# Microprocessors and Embedded Systems (in English);IMPe;S;6;Ex;UPSY;
# Microprocessors and Embedded Systems;IMP;W;6;Cr+Ex;UPSY;
# Modelling and Simulation;IMS;W;5;Cr+Ex;UITS;
# Multimedia Transmission over IP Networks;IMU;S;4;ClCr;UIFS;
# Digital Systems Design;INC;S;5;Cr+Ex;UPSY;
# Digital Systems Design (in English);INCe;W;5;Ex;UPSY;
# IT Service Design and Implementation;INI;W;4;ClCr;UIFS;
# Design of Computer Systems;INP;W;6;Cr+Ex;UPSY;
# Operating Systems;IOS;S;5;Cr+Ex;UITS;
# Computer Communications and Networks;IPK;S;4;Cr+Ex;UIFS;
# Principles of Programming Languages (in English);IPPe;S;5;Cr+Ex;UIFS;
# Principles of Programming Languages;IPP;S;5;Cr+Ex;UIFS;
# Programming Seminar;IPS;W;2;Cr;UITS;
# Peripheral Devices (in English);IPZe;S;3;Ex;UPSY;
# Peripheral Devices;IPZ;W;3;Ex;UPSY;
# Project Practice 1 (in English);IP1e;W;5;ClCr;UIFS;
# Project Practice 1 (in English);IP1e;S;5;ClCr;UIFS;
# Project Practice 1;IP1;W;5;ClCr;UIFS;
# Project Practice 2 (in English);IP2e;S;5;ClCr;UIFS;
# Project Practice 2;IP2;S;5;ClCr;UIFS;
# Project Practice 3;IP3;W;5;ClCr;UIFS;
# Network Applications and Network Administration;ISA;W;5;Cr+Ex;UIFS;
# PC Seminar;ISC;W;2;Cr;UIFS;
# Intelligent Systems;ISD;S;0;Ex;UITS;
# Scripting Languages;ISJ;S;5;Ex;UPGM;
# Seminar of Mathematics;ISM;W;2;Cr;UMAT;
# Signals and Systems;ISS;W;6;Ex;UPGM;
# Personal Computers;ITP;S;4;Ex;UPSY;
# Testing and Dynamic Analysis;ITS;S;5;Cr+Ex;UITS;
# Term Thesis (in English);ITTe;W;5;Cr;UIFS;
# Term Thesis;ITT;W;5;Cr;UPSY;
# User Interface Programming;ITU;W;5;ClCr;UPGM;
# User Interface Programming (in English);ITUe;W;5;ClCr;UPGM;
# Web Design;ITW;S;5;ClCr;UIFS;
# Web Design (in English);ITWe;W;5;ClCr;UIFS;
# Typography and Publishing;ITY;S;4;ClCr;UITS;
# Introduction to Software Engineering;IUS;W;5;Cr+Ex;UITS;
# Information Education and Literacy;IVG;W;1;Cr;DFIT-Kn;
# VHDL Seminar;IVH;S;4;ClCr;UPSY;
# Practical Aspects of Software Design;IVS;S;5;ClCr;UPGM;
# Bioinformatics;IV108;W;0;Ex;FI MU;
# Programming Apple Devices;IZA;S;5;Ex;UITS;
# Computer Graphics Principles;IZG;S;6;Cr+Ex;UPGM;
# Introduction to Programming Systems;IZP;W;7;Cr+Ex;UIFS;
# Fundamentals of Artificial Intelligence;IZU;S;4;Cr+Ex;UITS;
# Fundamentals of Artificial Intelligence (in English);IZUe;W;4;Cr+Ex;UITS;
# LAN Switching, Accessing the WAN (CCNA3+4);I2C;S;4;ClCr;UIFS;
# Ph.D. Test of English;JAD;W;0;Ex;UJAZ;
# Ph.D. Test of English;JAD;S;0;Ex;UJAZ;
# Conversation through Hot Current Issues;JA3;W;3;Cr+Ex;UJAZ;
# Conversation through Hot Current Issues;JA3;S;3;Cr+Ex;UJAZ;
# English for PhD Students;JA6D;W;0;Ex;UJAZ;
# Spanish for Beginners 2/2;JS2;S;3;Cr+Ex;UJAZ;
# Data Coding and Compression;KKO;S;5;Cr+Ex;UPSY;
# Classification and recognition;KRD;S;0;Ex;UPGM;
# Cryptography;KRY;S;5;Cr+Ex;UITS;
# Logic;LOG;S;5;Cr+Ex;ÚM OAAG;
# Mathematical Structures in Computer Science;MAT;W;5;Ex;ÚM OAAG;
# Modern Mathematical Methods in Informatics;MID;W;0;Ex;ÚM OAAG;
# Mathematical Logic;MLD;S;0;Ex;ÚM OAAG;
# Advanced Methods of 3D Scene Visualisation;MMD;W;0;Ex;UPGM;
# Project Management;MPR;S;5;Cr+Ex;UIFS;
# Modelling and Simulation;MSD;W;0;Ex;UITS;
# Multimedia;MUL;S;5;Ex;UPGM;
# Multimedia (in English);MULe;S;5;Ex;UPGM;
# Microsoft Windows Desktop Systems;IW1;W;5;Cr+Ex;UIFS;
# Microsoft Windows Server Systems;IW2;S;5;Cr+Ex;UIFS;
# Programming .NET and C#;IW5;W;5;ClCr;UIFS;
# Modern Methods of Speech Processing;MZD;W;0;Ex;UPGM;
# Design of Embedded Systems;NAV;S;5;Ex;UPSY;
# Projecting, Administration and Security;NSB;S;5;Cr+Ex;UIFS;
# Optics;OPD;W;0;Ex;UFYZ;
# Optimization;OPM;S;4;Cr+Ex;ÚM OSO;
# Optimal Control and Identification;ORID;W;0;Ex;UPGM;
# Advanced Assembly Languages;IPA;S;5;Ex;UITS;
# Advanced Biometric Systems;PBD;W;0;Ex;UITS;
# Advanced Bioinformatics;PBI;W;4;Ex;UPSY;
# Advanced Digital Systems;PCS;W;5;Ex;UPSY;
# Advanced Database Systems;PDB;W;5;Cr+Ex;UIFS;
# Applications of Parallel Computers;PDD;W;0;Ex;UPSY;
# Distributed Application Environment;PDI;W;5;Ex;UIFS;
# Data Communications, Computer Networks and Protocols;PDS;S;5;Ex;UIFS;
# Computer Graphics;PGD;W;0;Ex;UPGM;
# Advanced Computer Graphics (in English);PGPa;W;5;Ex;UPGM;
# Computer Graphics (in English);PGRe;W;5;Ex;UPGM;
# Computer Graphics;PGR;W;5;Ex;UPGM;
# Advanced Information Systems;PIS;S;5;Cr+Ex;UIFS;
# Project Manager;PMA;S;5;ClCr;UIFS;
# Advanced Techniques in Digital Design;PND;W;0;Ex;UPSY;
# Advanced Operating Systems;POS;S;5;Ex;UIFS;
# Computer Vision (in English);POVa;W;5;Ex;UPGM;
# Project Practice 1 (in English);PP1e;W;5;ClCr;UIFS;
# Project Practice 1 (in English);PP1e;S;5;ClCr;UIFS;
# Project Practice 1;PP1;S;5;ClCr;UIFS;
# Project Practice 2;PP2;W;5;ClCr;UIFS;
# Parallel and Distributed Algorithms;PRL;S;5;Cr+Ex;UITS;
# Robotics (in English);ROBa;W;5;Ex;UITS;
# Semester Project (in English);SEPe;W;5;ClCr;UPSY;
# Semester Project;SEP;W;5;ClCr;UPSY;
# Soft Computing;SFC;W;5;Cr+Ex;UITS;
# Intelligent Systems;SIN;W;5;Ex;UITS;
# Complexity (in English);SLOa;S;5;Ex;UITS;
# Simulation Tools and Techniques;SNT;S;5;Cr+Ex;UITS;
# Fault Tolerant Systems;SOD;S;0;Ex;UPSY;
# Fault Tolerant Systems;SPP;S;5;Cr+Ex;UPSY;
# Strategic Management of Information Systems;SRI;W;5;Ex;UIFS;
# Theory and Applications of Petri Nets;TAD;S;0;Ex;UITS;
# Application Development for Mobile Devices (in English);TAMa;W;5;ClCr;UPGM;
# Game Theory;THE;W;5;Cr+Ex;UITS;
# Modern Theoretical Computer Science;TID;W;0;Ex;UIFS;
# Theoretical Computer Science (in English);TINe;S;5;Cr+Ex;UITS;
# Theoretical Computer Science;TIN;W;7;Cr+Ex;UITS;
# Programming Language Theory;TJD;W;0;Ex;UIFS;
# Category Theory in Computer Science;TKD;S;0;Ex;ÚM OAAG;
# Computational Geometry;VGE;S;5;Ex;UPGM;
# Computer Art;VIN;W;5;ClCr;UPGM;
# Visualization and CAD (in English);VIZa;S;5;ClCr;UPGM;
# Higly Sophisticated Computations;VND;S;0;Ex;UITS;
# High Performance Computations (in English);VNVe;S;5;Ex;UITS;
# High Performance Computations;VNV;S;5;Ex;UITS;
# Selected Topics of Information Systems;VPD;S;0;Ex;UIFS;
# Computational Photography;VYF;S;5;ClCr;UPGM;
# Compiler Construction (in English);VYPa;W;5;Ex;UIFS;
# Internet Applications;WAP;S;5;Cr+Ex;UIFS;
# Corporate Economy;IZEP;W;4;Cr+Ex;ÚM;
# Natural Language Processing;ZPD;W;0;Ex;UPGM;
# Image Processing;ZPO;S;5;Ex;UPGM;
# Professional Practice, Abroad;ZPX;S;5;Cr;UPSY;
# Professional Practice, Abroad;ZPX;W;5;Cr;UPSY;
# Speech Signal Processing;ZRE;S;5;Ex;UPGM;
# Knowledge Discovery in Databases;ZZN;W;5;Cr+Ex;UIFS;
# Graph Algorithms (in English);GALe;W;5;Ex;UIFS;
# Graphical User Interfaces in Java (in English);GJAe;W;5;Cr+Ex;UPGM;
# Signals and Systems (in English);ISSe;W;6;Ex;UPGM;
# Physical Optics (in English);FYOe;S;5;Ex;UFYZ;
# Speech Signal Processing (in English);ZREe;S;5;Ex;UPGM;
# Java Programming Language (in English);IJAe;W;5;ClCr;UITS;
# Hardware/Software Codesign (in English);HSCe;W;5;Cr+Ex;UPSY;
# Advanced Database Systems (in English);PDBe;W;5;Cr+Ex;UIFS;
# Image Processing (in English);ZPOe;S;5;Ex;UPGM;
# The C# Programming Language;ICS;S;4;ClCr;UIFS;
# Mathematical Structures in Computer Science (in English);MATe;W;5;Ex;ÚM OAAG;
# Data Communications, Computer Networks and Protocols (in English);PDSe;S;5;Ex;UIFS;
# Computational Geometry (in English);VGEe;S;5;Ex;UPGM;
# Statistics, Stochastic Processes, Operations Research;DPC-MA1;W;4;Ex;UMAT;
# Optimization Methods and Queuing Theory;DPC-TK1;W;4;Ex;UTKO;
# Medical Imaging Systems;BPC-ZSL;S;5;Cr+Ex;UBMI;
# Introduction to Molecular Biology and Genetics;BPC-MOL;S;5;Cr+Ex;LF MU;
# Mathematics 2;BPC-MA2A;S;6;Cr+Ex;UMAT;
# Electrical Installations;MPC-EIC;S;5;ClCr;UTEE;
# Microelectronics in English;MPA-MEN;W;3;ClCr;UMEL;
# Optical Networks;MPC-OSE;W;5;Cr+Ex;UTKO;
# Electrical Engineering Tutorial;BPC-ELSA;W;2;Cr;UTEE;
# User Experience and Design of User Interfaces and Services (in English);UXIa;S;5;ClCr;UPGM;
# Digital Forensics (in English);DFAa;S;5;Ex;UIFS;
# 3D Printing and Digital Fabrication for Creative Industries 2;1DS-2;S;2;Cr;K3D;
# Visual Digital Game Styles 1;VSDH1;W;2;Cr;AHM;
# Visual Digital Game Styles 2;VSDH2;S;2;Cr;AHM;
# Game Studies;1HS-Z;W;3;Ex;FaVU;
# Digital Games Critical Analyses;1KADH-L;S;3;Ex;FaVU;
# Applied game studies – research and design;1AHS-L;W;3;Ex;FaVU;
# Radio Communication;MPC-RKO;W;6;Cr+Ex;UREL;
# Management;manP;W;5;Cr+Ex;ÚM;
# Marketing;marP;S;6;Cr+Ex;ÚM;
# Financial Markets;ftP;W;6;Cr+Ex;ÚE;
# Engineering Pedagogy and Didactics;XPC-IPD;S;5;Ex;UJAZ;
# Engineering Pedagogy and Didactics;XPC-IPD;W;5;Ex;UJAZ;
# Management Minimum;XPC-POM;W;4;Cr;UMEL;
# Culture of Speech and the Generation of Texts;XPC-KPT;W;5;Cr;UJAZ;
# Culture of Speech and the Generation of Texts;XPC-KPT;S;5;Cr;UJAZ;
# Safety in Electrical Engineering;XPC-ELB;S;2;Ex;UTEE;
# Pedagogical Psychology;XPC-PEP;S;5;Cr+Ex;UJAZ;
# Pedagogical Psychology;XPC-PEP;W;5;Cr+Ex;UJAZ;
# Headway Pre-Intermediate 1;BAN1;S;3;Cr+Ex;UJAZ;
# Headway Pre-Intermediate 1;BAN1;W;3;Cr+Ex;UJAZ;
# Distributed Application Environment (in English);PDIe;W;5;Ex;UIFS;
# Natural Language Processing (in English);ZPJa;W;5;Ex;UPGM;
# Master's Thesis (in English);DIPa;S;13;Cr;UPSY;
# Semester Project (in English);SEPa;W;5;ClCr;UPSY;
# Secure Hardware Devices;BZA;S;5;Ex;UITS;
# Linear Algebra;ILG;W;5;Cr+Ex;UMAT;
# Mathematical Analysis 1;IMA1;S;4;Cr+Ex;UMAT;
# Discrete Mathematics;IDM;W;4;Cr+Ex;UMAT;
# Mathematical Analysis 2;IMA2;W;4;Cr+Ex;UMAT;
# Probability and Statistics;IPT;W;5;Cr+Ex;UMAT;
# German for Specific Purposes I;N7;W;4;Cr+Ex;ÚJ;
# German for Specific Purposes II;N8;S;4;Cr+Ex;ÚJ;
# Machine Learning and Recognition;SUR;S;5;Ex;UPGM;
# Convolutional Neural Networks;KNN;S;5;ClCr;UPGM;
# Statistics and Probability;MSP;W;6;Cr+Ex;ÚM OSO;
# Artificial Intelligence and Machine Learning;SUI;W;5;Ex;UPGM;
# Bayesian Models for Machine Learning (in English);BAYa;W;5;Ex;UPGM;
# Digital Signal Processing (in English);CZSa;W;5;Ex;UPSY;
# Cyber-Physical Systems Design (in English);CPSa;S;5;Cr+Ex;UPGM;
# Parallel Computations on GPU;PCG;W;5;Ex;UPSY;
# Principles and Design of IoT;TOI;S;5;Cr+Ex;UITS;
# Practical Parallel Programming;PPP;S;5;Cr+Ex;UPSY;
# Real-Time Systems (in English);RTSa;S;5;Ex;UPSY;
# Data Storage and Preparation;UPA;W;5;Cr+Ex;UIFS;
# Automated Testing and Dynamic Analysis;ATA;S;5;Ex;UITS;
# CCNA Cybersecurity Operations (in English);CSOa;S;5;ClCr;UIFS;
# Sensors and Measurement;SEM;W;5;Cr+Ex;UITS;
# Modern Trends in Informatics (in English);MTIa;S;4;ClCr;UPGM;
# Computation Systems Architectures;AVS;W;5;Cr+Ex;UPSY;
# Static Analysis and Verification;SAV;W;5;Cr+Ex;UITS;
# Model-Based Analysis;MBA;S;5;Ex;UITS;
# Graphic design topics of today;ATGD;W;2;Cr;KTDU;
# Regulated Grammars and Automata;RGD;W;0;Ex;UIFS;
# Scientific Publishing A to Z;VDD;W;0;Ex;ÚK;
# Business Laboratory;PLAB;S;4;ClCr;ÚM;
# Digital Marketing and Social Media;DMSM;W;5;ClCr;ÚM;
# E-commerce;EC;W;6;ClCr;ÚI;
# Basic Elements of Financing;ZFI;S;6;Cr+Ex;ÚF;
# Information Systems Law;PRIS;S;5;Ex;ÚI;
# Practical English 4;BPC-PA4;S;5;Ex;UJAZ;
# Russian for Beginners 2;XPC-RU2;S;3;ClCr;UJAZ;
# Practical English 3;BPC-PA3;W;5;Ex;UJAZ;
# Physics in Electrical Engineering;BPC-FYE;W;5;Cr+Ex;UFYZ;
# Russian for Beginners 1;XPC-RU1;W;3;ClCr;UJAZ;
# Practical English 1;BPC-PA1;W;5;Ex;UJAZ;
# Practical English 2;BPC-PA2;S;5;Ex;UJAZ;
# German for Beginners 2;XPC-NE2;S;3;ClCr;UJAZ;
# German for Beginners 1;XPC-NE1;W;3;ClCr;UJAZ;
# Business English;XPC-BEN;S;3;Cr+Ex;UJAZ;
# Data Analysis and Visualization in Python;IZV;W;4;ClCr;UPSY;
# Selected Chapters on Mathematics;MAD;S;0;Ex;UITS;
# Earthen Architecture;HLS-KE;S;3;ClCr;US;
# Systems Biology;MPA-SYS;S;5;Cr+Ex;UBMI;
# CCNP Enterprise: Core Networking (ENCOR);CE1;W;5;ClCr;UIFS;
# CCNP Enterprise: Advanced Routing (ENARSI);CE2;S;5;ClCr;UIFS;
# Blockchain and Decentralised Applicatons;BDA;S;5;Cr+Ex;UITS;
# Molecular Biology;MPA-MOL;W;6;Cr+Ex;UBMI;
# Advanced Communication Systems;PKSa;W;5;Cr+Ex;UIFS;
# Biometric Systems (in English);BIOe;W;5;Cr+Ex;UITS;
# Project Practice 2 (in English);PP2e;S;5;ClCr;UIFS;
# Introduction to Game Development;1ZHERV;W;4;ClCr;AHM;
# Circle Consultations;IKK;W;0;-;UPGM;
# Seminar of Discrete Mathematics and Logics;SDL;W;1;Cr;UITS;
# Year Project 1;YP1a;W;4;Cr;FIT;
# Year Project 2;YP2a;S;4;ClCr;UPGM;
# Essentials of Work and Study in Research and Technology 1;WP1a;W;1;Cr;UPGM;
# Essentials of Work and Study in Research and Technology 2;WP2a;S;1;Cr;UPGM;
# French for Beginners 1;XPC-FR1;W;3;ClCr;UJAZ;
# French for Beginners 2;XPC-FR2;S;3;ClCr;UJAZ;
# German for Lower-Intermediate 1;XPC-NE3;W;3;ClCr;UJAZ;
# German for Lower-Intermediate 2;XPC-NE4;S;3;ClCr;UJAZ;
# English exam at level B1;ZAN4;W;1;Ex;UJAZ;
# General English Exam B1;GEN;S;1;Ex;ÚJ;
# General English Exam B1;GEN;W;1;Ex;ÚJ;
# Secure Coding;SCO;W;5;Cr+Ex;UITS;
# Brain Computer Interface;BRIa;W;5;Ex;UPSY;
# Introduction to Logic for Computer Science;IZLO;S;2;Ex;UITS;
# Data Warehousing;DS_2;W;5;Cr+Ex;UITS;
# Signals and Systems;ISSk;W;6;Ex;UPGM;
# Advanced Topics in Neuroimaging;ATND;S;0;Ex;UPSY;
# CNC Machining – Robots in Artistic Practice;1CNCO;S;2;Cr;K3D;
# Italian for Beginners 1;XPC-ITA1;W;3;ClCr;UJAZ;
# Italian for Beginners 2;XPC-ITA2;S;3;ClCr;UJAZ;
# Ontologie a sémantický web;SWD;W;0;Ex;UIFS;
